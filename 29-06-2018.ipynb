# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import numpy as np
import pandas as pd
df=pd.read_csv('C:\\Users\\malavika.c\\Desktop\\Analytics6\\Home Credit Default Risk.csv')
df.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#               ...              FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# ...

# %%
df.loc[0:2,['TARGET','NAME_CONTRACT_TYPE']]
# Out:
#    TARGET NAME_CONTRACT_TYPE
# 0       1         Cash loans
# 1       0         Cash loans
# 2       0    Revolving loans

# %%
df.loc[0,'CODE_GENDER']
# Out:
# 'M'

# %%
df.index
# Out:
# RangeIndex(start=0, stop=307511, step=1)

# %%
df.loc[df.CODE_GENDER=='F','CODE_GENDER']
# Out:
# 1         F
# 3         F
# 6         F
# 8         F
# 10        F
# 11        F
# 12        F
# 14        F
# 17        F
# 18        F
# 19        F
# 21        F
# 22        F
# 23        F
# 25        F
# 26        F
# 30        F
# 31        F
# 32        F
# 34        F
# 35        F
# 36        F
# 38        F
# 41        F
# 42        F
# 43        F
# 45        F
# 46        F
# 47        F
# 48        F
#          ..
# 307471    F
# 307472    F
# 307473    F
# 307475    F
# 307476    F
# 307477    F
# 307478    F
# 307479    F
# 307480    F
# 307482    F
# 307483    F
# 307484    F
# 307485    F
# 307486    F
# 307488    F
# 307489    F
# 307493    F
# 307496    F
# 307497    F
# 307499    F
# 307500    F
# 307501    F
# 307502    F
# 307503    F
# 307504    F
# 307505    F
# 307507    F
# 307508    F
# 307509    F
# 307510    F
# Name: CODE_GENDER, Length: 202448, dtype: object

# %%
df.ix[0:2,0:2]
# Out:
#    SK_ID_CURR  TARGET
# 0      100002       1
# 1      100003       0
# 2      100004       0

# %%
df.info(memory_usage=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Columns: 122 entries, SK_ID_CURR to AMT_REQ_CREDIT_BUREAU_YEAR
# dtypes: float64(65), int64(41), object(16)
# memory usage: 286.2+ MB

# %%
df.memory_usage(deep=True)
# Out:
# Index                               80
# SK_ID_CURR                     2460088
# TARGET                         2460088
# NAME_CONTRACT_TYPE            20749632
# CODE_GENDER                   19065674
# FLAG_OWN_CAR                  19065682
# FLAG_OWN_REALTY               19065682
# CNT_CHILDREN                   2460088
# AMT_INCOME_TOTAL               2460088
# AMT_CREDIT                     2460088
# AMT_ANNUITY                    2460088
# AMT_GOODS_PRICE                2460088
# NAME_TYPE_SUITE               21186762
# NAME_INCOME_TYPE              20852813
# NAME_EDUCATION_TYPE           25293683
# NAME_FAMILY_STATUS            20487265
# NAME_HOUSING_TYPE             22694238
# REGION_POPULATION_RELATIVE     2460088
# DAYS_BIRTH                     2460088
# DAYS_EMPLOYED                  2460088
# DAYS_REGISTRATION              2460088
# DAYS_ID_PUBLISH                2460088
# OWN_CAR_AGE                    2460088
# FLAG_MOBIL                     2460088
# ...

# %%
pd.get_option('display.max_rows')
# Out:
# 60

# %%
df
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0           100002       1         Cash loans           M            N
# 1           100003       0         Cash loans           F            N
# 2           100004       0    Revolving loans           M            Y
# 3           100006       0         Cash loans           F            N
# 4           100007       0         Cash loans           M            N
# 5           100008       0         Cash loans           M            N
# 6           100009       0         Cash loans           F            Y
# 7           100010       0         Cash loans           M            Y
# 8           100011       0         Cash loans           F            N
# 9           100012       0    Revolving loans           M            N
# 10          100014       0         Cash loans           F            N
# 11          100015       0         Cash loans           F            N
# ...

# %%
pd.set_option('display.max_rows',100)

# %%
df
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0           100002       1         Cash loans           M            N
# 1           100003       0         Cash loans           F            N
# 2           100004       0    Revolving loans           M            Y
# 3           100006       0         Cash loans           F            N
# 4           100007       0         Cash loans           M            N
# 5           100008       0         Cash loans           M            N
# 6           100009       0         Cash loans           F            Y
# 7           100010       0         Cash loans           M            Y
# 8           100011       0         Cash loans           F            N
# 9           100012       0    Revolving loans           M            N
# 10          100014       0         Cash loans           F            N
# 11          100015       0         Cash loans           F            N
# ...

# %%
pd.set_option('display.max_rows',None)# 'None- all rows' huge num of rows leads to memory error

# %%
df.head()
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#               ...              FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# ...

# %%
import seaborn as sns
g=sns.FacetGrid(df,row='FLAG_OWN_CAR',col='CODE_GENDER')

# %%
g=sns.FacetGrid(df,row='FLAG_OWN_CAR',col='CODE_GENDER')
g.map(plt.hist,'AMT_CREDIT')

# %%
g=sns.FacetGrid(df,row='FLAG_OWN_CAR',col='CODE_GENDER')
g.map(plt.scatter,'AMT_CREDIT','AMT_INCOME_TOTAL')

# %%
df.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER',
#        'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL',
#        'AMT_CREDIT', 'AMT_ANNUITY',
#        ...
#        'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20',
#        'FLAG_DOCUMENT_21', 'AMT_REQ_CREDIT_BUREAU_HOUR',
#        'AMT_REQ_CREDIT_BUREAU_DAY', 'AMT_REQ_CREDIT_BUREAU_WEEK',
#        'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT',
#        'AMT_REQ_CREDIT_BUREAU_YEAR'],
#       dtype='object', length=122)

# %%
df1=df.iloc[0:26,0:11]

# %%
df1
# Out:
#     SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0       100002       1         Cash loans           M            N
# 1       100003       0         Cash loans           F            N
# 2       100004       0    Revolving loans           M            Y
# 3       100006       0         Cash loans           F            N
# 4       100007       0         Cash loans           M            N
# 5       100008       0         Cash loans           M            N
# 6       100009       0         Cash loans           F            Y
# 7       100010       0         Cash loans           M            Y
# 8       100011       0         Cash loans           F            N
# 9       100012       0    Revolving loans           M            N
# 10      100014       0         Cash loans           F            N
# 11      100015       0         Cash loans           F            N
# 12      100016       0         Cash loans           F            N
# ...

# %%
x=sns.PairGrid(df1)

# %%
x=sns.PairGrid(df1)
x.map(plt.scatter)

# %%
x=sns.PairGrid(df1)
x.map_diag(plt.hist)
x.map_upper(sns.violinplot)
x.map_lower(sns.swarmplot)

# %%
y=sns.JointGrid(x='AMT_CREDIT',y='AMT_ANNUITY',data=df1)

# %%
y=sns.JointGrid(x='AMT_CREDIT',y='AMT_ANNUITY',data=df1)
y.plot(sns.regplot,sns.kdeplot)

# %%
plt.scatter(x='AMT_CREDIT',y='AMT_ANNUITY',data=df1)
