# %%
import pandas as pd
import numpy as np
pd.dataframe(np.random(5,5))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-870bcb8fd91e> in <module>()
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 pd.dataframe(np.random(5,5))
#
# AttributeError: module 'pandas' has no attribute 'dataframe'

# %%
np.random.randn(10,10)
# Out:
# array([[ 0.38286967,  0.82612646, -1.67639353,  0.55566784, -0.72326794,
#         -0.44119008, -0.66681662, -0.04669236, -2.80315758, -0.19642675],
#        [ 0.47375051,  1.05120616, -0.91578554,  0.1819204 ,  0.32578494,
#         -0.32113748, -0.24021288,  0.6873572 ,  2.0344231 , -0.23089128],
#        [-0.19055872, -1.02765881, -1.33717612, -1.32320696,  0.21191192,
#          1.52653849,  0.39755751,  1.44338707, -0.41538289,  1.55904663],
#        [ 0.20432156,  1.34566828, -1.39032312,  1.7168883 , -1.35891411,
#         -0.43396705,  0.16753775, -0.46577609,  1.32472038,  2.15103386],
#        [-0.40610988,  1.18732916, -0.33825747,  0.50205607, -0.50725502,
#          0.78090987,  0.33519843, -0.89627598,  0.01957983, -0.01156213],
#        [ 0.89511381,  0.27780503,  1.44227026, -0.25942925,  1.79630294,
#         -0.88047711,  2.02233383,  0.67961173, -1.79969404, -1.16866387],
#        [-1.34015324, -0.19133625,  0.77179874, -0.37328398,  0.63194284,
# ...

# %%
pd.DataFrame(np.random.randn(2,2),index=["a","b"],columns=["1","2"])
# Out:
#           1         2
# a -0.650276 -1.084275
# b -1.135125  0.385011

# %%
import numpy as np
np.random.randn(2,2)
# Out:
# array([[ 0.56551825,  0.30874664],
#        [-0.40178212,  1.64173859]])

# %%
import pandas as pd
pd.DataFrame(np.random.randn(2,2),index=["a","b"],columns=["1","2"])
# Out:
#           1         2
# a -1.233369  0.456922
# b -0.221338 -1.626535

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("C:\\Users\\29265\\Downloads\\train.csv")
a=list(df.corr()[:0])

df=df[a]


for i in a:
   
    for j in a:
        plt.figure()
        plt.scatter(i,j)
        
        
#a=list(df['PassengerId'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-9e39aead698d> in <module>()
#      12     for j in a:
#      13         plt.figure()
# ---> 14         plt.scatter(i,j)
#      15
#      16
#
# C:\Users\29265\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3432                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3433                          linewidths=linewidths, verts=verts,
# -> 3434                          edgecolors=edgecolors, data=data, **kwargs)
#    3435     finally:
#    3436         ax._hold = washold
#
# C:\Users\29265\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
a=df.columns

# %%
a
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
for i in a:
    for j in a:
        plt.scatter(i,j)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-e95ec47271d9> in <module>()
#       1 for i in a:
#       2     for j in a:
# ----> 3         plt.scatter(i,j)
#
# C:\Users\29265\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3432                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3433                          linewidths=linewidths, verts=verts,
# -> 3434                          edgecolors=edgecolors, data=data, **kwargs)
#    3435     finally:
#    3436         ax._hold = washold
#
# C:\Users\29265\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1895                     warnings.warn(msg % (label_namer, func.__name__),
# ...

# %%
df.fillna(2,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2220b1abde66> in <module>()
# ----> 1 df.fillna(2,inplace=True)
#
# NameError: name 'df' is not defined

# %%
for i in a:
   
    for j in a:
        plt.figure()
        plt.scatter(i,j)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-af642a02e879> in <module>()
#       3     for j in a:
#       4         plt.figure()
# ----> 5         plt.scatter(i,j)
#       6
#
# C:\Users\29265\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3432                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3433                          linewidths=linewidths, verts=verts,
# -> 3434                          edgecolors=edgecolors, data=data, **kwargs)
#    3435     finally:
#    3436         ax._hold = washold
#
# C:\Users\29265\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1895                     warnings.warn(msg % (label_namer, func.__name__),
# ...

# %%
sns.pairplot(df)

# %%
df
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch      Fare
# 0              1         0       3  22.0      1      0    7.2500
# 1              2         1       1  38.0      1      0   71.2833
# 2              3         1       3  26.0      0      0    7.9250
# 3              4         1       1  35.0      1      0   53.1000
# 4              5         0       3  35.0      0      0    8.0500
# 5              6         0       3   2.0      0      0    8.4583
# 6              7         0       1  54.0      0      0   51.8625
# 7              8         0       3   2.0      3      1   21.0750
# 8              9         1       3  27.0      0      2   11.1333
# 9             10         1       2  14.0      1      0   30.0708
# 10            11         1       3   4.0      1      1   16.7000
# 11            12         1       1  58.0      0      0   26.5500
# 12            13         0       3  20.0      0      0    8.0500
# ...

# %%
df.set_index("Parch",inplace=True)

df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\29265\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20405)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20359)()
#
# KeyError: 'Parch'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
df
# Out:
#        PassengerId  Survived   Age  SibSp      Fare
# Parch
# 0                1         0  22.0      1    7.2500
# 0                2         1  38.0      1   71.2833
# 0                3         1  26.0      0    7.9250
# 0                4         1  35.0      1   53.1000
# 0                5         0  35.0      0    8.0500
# 0                6         0   2.0      0    8.4583
# 0                7         0  54.0      0   51.8625
# 1                8         0   2.0      3   21.0750
# 2                9         1  27.0      0   11.1333
# 0               10         1  14.0      1   30.0708
# 1               11         1   4.0      1   16.7000
# 0               12         1  58.0      0   26.5500
# 0               13         0  20.0      0    8.0500
# 5               14         0  39.0      1   31.2750
# 0               15         0  14.0      0    7.8542
# 0               16         1  55.0      0   16.0000
# 1               17         0   2.0      4   29.1250
# ...

# %%
df.reset_index()
# Out:
#      Parch  PassengerId  Survived   Age  SibSp      Fare
# 0        0            1         0  22.0      1    7.2500
# 1        0            2         1  38.0      1   71.2833
# 2        0            3         1  26.0      0    7.9250
# 3        0            4         1  35.0      1   53.1000
# 4        0            5         0  35.0      0    8.0500
# 5        0            6         0   2.0      0    8.4583
# 6        0            7         0  54.0      0   51.8625
# 7        1            8         0   2.0      3   21.0750
# 8        2            9         1  27.0      0   11.1333
# 9        0           10         1  14.0      1   30.0708
# 10       1           11         1   4.0      1   16.7000
# 11       0           12         1  58.0      0   26.5500
# 12       0           13         0  20.0      0    8.0500
# 13       5           14         0  39.0      1   31.2750
# 14       0           15         0  14.0      0    7.8542
# ...

# %%
df1=pd.read_excel("C:\\Users\\29265\\Desktop\\data.xlsx",sheetname='Sheet1')
df2=pd.read_excel("C:\\Users\\29265\\Desktop\\data.xlsx",sheetname='Sheet2')
pd.merge(df1,df2,how='inner')
# Out:
#     str  sales  units  txns
# 0  str2     30      1  2000
# 1  str3     20      1  2000
# 2  str4     20      1  2000
# 3  str5     20      1  2000

# %%
pd.merge(df2,df1,how='left',on='str')
# Out:
#     str  sales_x  units_x  txns_x  sales_y  units_y  txns_y
# 0  str1       34        1    2348       20        1    2000
# 1  str2       30        1    2000       30        1    2000
# 2  str3       20        1    2000       20        1    2000
# 3  str4       20        1    2000       20        1    2000
# 4  str5       20        1    2000       20        1    2000
# 5  str6       40        1    2000       40        1    2000

# %%
pd.merge(df2,df1,how='outer',on='str',indicator=True)
# Out:
#     str  sales_x  units_x  txns_x  sales_y  units_y  txns_y _merge
# 0  str1       34        1    2348       20        1    2000   both
# 1  str2       30        1    2000       30        1    2000   both
# 2  str3       20        1    2000       20        1    2000   both
# 3  str4       20        1    2000       20        1    2000   both
# 4  str5       20        1    2000       20        1    2000   both
# 5  str6       40        1    2000       40        1    2000   both

# %%
pd.merge(df2,df1,how='outer',on='str',indicator=True)
# Out:
#     str  sales_x  units_x  txns_x  sales_y  units_y  txns_y      _merge
# 0  str1     34.0      1.0  2348.0     20.0      1.0  2000.0        both
# 1  str2     30.0      1.0  2000.0     30.0      1.0  2000.0        both
# 2  str3     20.0      1.0  2000.0     20.0      1.0  2000.0        both
# 3  str4     20.0      1.0  2000.0     20.0      1.0  2000.0        both
# 4  str5     20.0      1.0  2000.0     20.0      1.0  2000.0        both
# 5  str6     40.0      1.0  2000.0      NaN      NaN     NaN   left_only
# 6  str7      NaN      NaN     NaN     40.0      1.0  2000.0  right_only

# %%
a=pd.merge(df2,df1,how='outer',on='str',indicator=True)
a[a['_merge']=='left_only']
# Out:
#     str  sales_x  units_x  txns_x  sales_y  units_y  txns_y     _merge
# 5  str6     40.0      1.0  2000.0      NaN      NaN     NaN  left_only

# %%
df3=pd.read_excel("C:\\Users\\29265\\Desktop\\data.xlsx",sheetname='Sheet3')
df3
# Out:
#     str  sales  units    txns
# 0  str1   20.0      1  2000.0
# 1  str2   30.0      1  2000.0
# 2  str3    NaN      1  2000.0
# 3  str4   20.0      1  2000.0
# 4  str5    NaN      1  2000.0
# 5  str7   40.0      1     NaN

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
df3.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-af101926847a> in <module>()
# ----> 1 df3.isna().sum()
#
# C:\Users\29265\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'isna'
