# %%
#application_train
import pandas as pd
df=pd.read_csv("C:\\Users\\29265\\Downloads\\train.csv")
# Out:
# C:\Users\29265\AppData\Local\Continuum\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pd.test()
# Out:
# running: pytest --skip-slow --skip-network C:\Users\29265\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas
# ============================= test session starts =============================
# platform win32 -- Python 3.6.1, pytest-3.0.7, py-1.4.33, pluggy-0.4.0
# rootdir: C:\Users\29265, inifile:
# collected 10236 items / 2 skipped
#
# AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\tests\test_algos.py ........................................................................................
# AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\tests\test_base.py .........................
# AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\tests\test_categorical.py ...................................................................................FFFFFF..FFFFFF................................................
# AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\tests\test_common.py ..............
# ...

# %%
#only try with string kind of data type
df['new_merge']=df.NAME_CONTRACT_TYPE+','+df.CODE_GENDER
df.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#          ...          FLAG_DOCUMENT_19 FLAG_DOCUMENT_20 FLAG_DOCUMENT_21  \
# ...

# %%
df.describe(include=['object'])
# Out:
#        NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# count              307511      307511       307511          307511
# unique                  2           3            2               2
# top            Cash loans           F            N               Y
# freq               278232      202448       202924          213312
#
#        NAME_TYPE_SUITE NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# count           306219           307511                         307511
# unique               7                8                              5
# top      Unaccompanied          Working  Secondary / secondary special
# freq            248526           158774                         218391
#
#        NAME_FAMILY_STATUS  NAME_HOUSING_TYPE OCCUPATION_TYPE  \
# count              307511             307511          211120
# unique                  6                  6              18
# top               Married  House / apartment        Laborers
# ...

# %%
df.rename(columns={'CODE_GENDER':'Gender'},inplace=True)
df.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'Gender', 'FLAG_OWN_CAR',
#        'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT',
#        'AMT_ANNUITY',
#        ...
#        'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20',
#        'FLAG_DOCUMENT_21', 'AMT_REQ_CREDIT_BUREAU_HOUR',
#        'AMT_REQ_CREDIT_BUREAU_DAY', 'AMT_REQ_CREDIT_BUREAU_WEEK',
#        'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT',
#        'AMT_REQ_CREDIT_BUREAU_YEAR'],
#       dtype='object', length=122)

# %%
df.columns = df.columns.str.replace(' ', '_')
df.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'Gender', 'FLAG_OWN_CAR',
#        'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT',
#        'AMT_ANNUITY',
#        ...
#        'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20', 'FLAG_DOCUMENT_21',
#        'AMT_REQ_CREDIT_BUREAU_HOUR', 'AMT_REQ_CREDIT_BUREAU_DAY',
#        'AMT_REQ_CREDIT_BUREAU_WEEK', 'AMT_REQ_CREDIT_BUREAU_MON',
#        'AMT_REQ_CREDIT_BUREAU_QRT', 'AMT_REQ_CREDIT_BUREAU_YEAR', 'new_merge'],
#       dtype='object', length=123)

# %%
#df.drop('Gender',axis=1,inplace=True)
df=df.sample(1000)

# %%
df.drop('Gender',axis=1,inplace=True)

# %%
df.head()
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 220865      355857       0         Cash loans            Y               Y
# 30830       135787       0         Cash loans            N               Y
# 139505      261751       0         Cash loans            N               Y
# 194690      325746       0    Revolving loans            Y               Y
# 148988      272738       0         Cash loans            N               Y
#
#         CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 220865             0          225000.0   1065681.0      45279.0
# 30830              0          450000.0    677664.0      24471.0
# 139505             0          135000.0    497520.0      33376.5
# 194690             0          135000.0    135000.0       6750.0
# 148988             2          112500.0    350860.5      19161.0
#
#         AMT_GOODS_PRICE        ...         FLAG_DOCUMENT_19 FLAG_DOCUMENT_20  \
# ...

# %%
df.AMT_INCOME_TOTAL.sort_values(ascending=False).head()
# Out:
# 204039    900000.0
# 297454    675000.0
# 188022    675000.0
# 86692     675000.0
# 104395    675000.0
# Name: AMT_INCOME_TOTAL, dtype: float64

# %%
a=[]
for i in df.CNT_CHILDREN:
    if(i==0):
        a.append(i)
    else:
        a.append(100)
        
df['append_xyz']=a
df.head()
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 301970      449844       0         Cash loans            Y               Y
# 53611       162098       1    Revolving loans            N               Y
# 218038      352615       0         Cash loans            Y               Y
# 120926      240207       0         Cash loans            N               N
# 276385      420261       0         Cash loans            Y               N
#
#         CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 301970             0          270000.0    937287.0      57339.0
# 53611              0           49500.0    157500.0       7875.0
# 218038             2          315000.0   1436850.0      46480.5
# 120926             0           90000.0    450000.0      16164.0
# 276385             0          270000.0    675000.0      36616.5
#
#         AMT_GOODS_PRICE     ...     FLAG_DOCUMENT_19 FLAG_DOCUMENT_20  \
# ...

# %%
print(True or False)
# Out:
# True

# %%
df[(df.TARGET==0) & (df.CNT_CHILDREN==0)]
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 301970      449844       0         Cash loans            Y               Y
# 120926      240207       0         Cash loans            N               N
# 276385      420261       0         Cash loans            Y               N
# 303300      451404       0    Revolving loans            N               Y
# 220791      355772       0         Cash loans            Y               Y
# 52604       160921       0         Cash loans            N               N
# 139316      261537       0         Cash loans            N               N
# 127918      248360       0         Cash loans            N               Y
# 20162       123519       0         Cash loans            N               Y
# 256905      397298       0    Revolving loans            N               Y
# 286303      431586       0         Cash loans            Y               Y
# ...

# %%
#Printing what precentage of values are null values
# to count the number of null values : df.isnull().sum()
# count the number of rows : df.isnull().count()

total = df.isnull().sum().sort_values(ascending = False)
percent = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending = False)

missing_application_train_data=pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

missing_application_train_data.head(20)




def make_meta_dataframe(df):
    data = []
    for col in df.columns:
        if df[col].dtype == 'float64':
            level = 'interval'
        elif df[col].dtype == 'int64':
            level = 'ordinal'
        elif df[col].dtype == 'object':
            level = 'categorical'

        col_dict = {
            'varname': col,
            'level': level,
            'dtype': df[col].dtype,
            'response_rate': 100 * df[col].notnull().sum() / df.shape[0]
        }
        data.append(col_dict)

    meta = pd.DataFrame(data, columns=['varname', 'level', 'dtype', 'response_rate'])
    meta.set_index('varname', inplace=True)
    return meta

# %%
df.isna().sum()
# Out:
# SK_ID_CURR                      0
# TARGET                          0
# NAME_CONTRACT_TYPE              0
# FLAG_OWN_CAR                    0
# FLAG_OWN_REALTY                 0
# CNT_CHILDREN                    0
# AMT_INCOME_TOTAL                0
# AMT_CREDIT                      0
# AMT_ANNUITY                     0
# AMT_GOODS_PRICE                 1
# NAME_TYPE_SUITE                 1
# NAME_INCOME_TYPE                0
# NAME_EDUCATION_TYPE             0
# NAME_FAMILY_STATUS              0
# NAME_HOUSING_TYPE               0
# REGION_POPULATION_RELATIVE      0
# DAYS_BIRTH                      0
# DAYS_EMPLOYED                   0
# DAYS_REGISTRATION               0
# DAYS_ID_PUBLISH                 0
# OWN_CAR_AGE                   660
# FLAG_MOBIL                      0
# FLAG_EMP_PHONE                  0
# FLAG_WORK_PHONE                 0
# FLAG_CONT_MOBILE                0
# FLAG_PHONE                      0
# FLAG_EMAIL                      0
# ...

# %%
percent = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending = False)
percent
# Out:
# COMMONAREA_MEDI                70.8
# COMMONAREA_AVG                 70.8
# COMMONAREA_MODE                70.8
# NONLIVINGAPARTMENTS_MEDI       70.0
# NONLIVINGAPARTMENTS_MODE       70.0
# NONLIVINGAPARTMENTS_AVG        70.0
# FONDKAPREMONT_MODE             69.4
# LIVINGAPARTMENTS_AVG           68.6
# LIVINGAPARTMENTS_MODE          68.6
# LIVINGAPARTMENTS_MEDI          68.6
# FLOORSMIN_MEDI                 68.2
# FLOORSMIN_AVG                  68.2
# FLOORSMIN_MODE                 68.2
# YEARS_BUILD_AVG                66.7
# YEARS_BUILD_MEDI               66.7
# YEARS_BUILD_MODE               66.7
# OWN_CAR_AGE                    66.0
# BASEMENTAREA_MODE              60.2
# BASEMENTAREA_AVG               60.2
# BASEMENTAREA_MEDI              60.2
# LANDAREA_AVG                   60.0
# LANDAREA_MODE                  60.0
# LANDAREA_MEDI                  60.0
# NONLIVINGAREA_MEDI             56.3
# NONLIVINGAREA_MODE             56.3
# NONLIVINGAREA_AVG              56.3
# ...

# %%
df.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'FLAG_OWN_CAR',
#        'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT',
#        'AMT_ANNUITY', 'AMT_GOODS_PRICE',
#        ...
#        'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20', 'FLAG_DOCUMENT_21',
#        'AMT_REQ_CREDIT_BUREAU_HOUR', 'AMT_REQ_CREDIT_BUREAU_DAY',
#        'AMT_REQ_CREDIT_BUREAU_WEEK', 'AMT_REQ_CREDIT_BUREAU_MON',
#        'AMT_REQ_CREDIT_BUREAU_QRT', 'AMT_REQ_CREDIT_BUREAU_YEAR',
#        'append_xyz'],
#       dtype='object', length=122)

# %%
total = df.isnull().sum().sort_values(ascending = False)
percent = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending = False)

missing_application_train_data=pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

missing_application_train_data.head(20)
# Out:
#                           Total  Percent
# COMMONAREA_MEDI             708     70.8
# COMMONAREA_AVG              708     70.8
# COMMONAREA_MODE             708     70.8
# NONLIVINGAPARTMENTS_MEDI    700     70.0
# NONLIVINGAPARTMENTS_MODE    700     70.0
# NONLIVINGAPARTMENTS_AVG     700     70.0
# FONDKAPREMONT_MODE          694     69.4
# LIVINGAPARTMENTS_AVG        686     68.6
# LIVINGAPARTMENTS_MODE       686     68.6
# LIVINGAPARTMENTS_MEDI       686     68.6
# FLOORSMIN_MEDI              682     68.2
# FLOORSMIN_AVG               682     68.2
# FLOORSMIN_MODE              682     68.2
# YEARS_BUILD_AVG             667     66.7
# YEARS_BUILD_MEDI            667     66.7
# YEARS_BUILD_MODE            667     66.7
# OWN_CAR_AGE                 660     66.0
# BASEMENTAREA_MODE           602     60.2
# BASEMENTAREA_AVG            602     60.2
# BASEMENTAREA_MEDI           602     60.2

# %%
def make_meta_dataframe(df):
    data = []
    for col in df.columns:
        if df[col].dtype == 'float64':
            level = 'interval'
        elif df[col].dtype == 'int64':
            level = 'ordinal'
        elif df[col].dtype == 'object':
            level = 'categorical'

        col_dict = {
            'varname': col,
            'level': level,
            'dtype': df[col].dtype,
            'response_rate': 100 * df[col].notnull().sum() / df.shape[0]
        }
        data.append(col_dict)
        

    meta = pd.DataFrame(data, columns=['varname', 'level', 'dtype', 'response_rate'])
    meta.set_index('varname', inplace=True)
    return meta

# %%
meta1=make_meta_dataframe(df)
meta1
# Out:
#                      level   dtype  response_rate
# varname
# Store              ordinal   int64          100.0
# DayOfWeek          ordinal   int64          100.0
# Date           categorical  object          100.0
# Sales              ordinal   int64          100.0
# Customers          ordinal   int64          100.0
# Open               ordinal   int64          100.0
# Promo              ordinal   int64          100.0
# StateHoliday   categorical  object          100.0
# SchoolHoliday      ordinal   int64          100.0

# %%
#to change data type
df.dtypes

# %%
df['NAME_CONTRACT_TYPE'].value_counts()
# Out:
# Cash loans         278232
# Revolving loans     29279
# Name: NAME_CONTRACT_TYPE, dtype: int64

# %%
df['NAME_CONTRACT_TYPE'].value_counts(normalize=True)
# Out:
# Cash loans         0.904787
# Revolving loans    0.095213
# Name: NAME_CONTRACT_TYPE, dtype: float64

# %%
df.loc[0:3, 'NAME_CONTRACT_TYPE']
# Out:
# 0         Cash loans
# 1         Cash loans
# 2    Revolving loans
# 3         Cash loans
# Name: NAME_CONTRACT_TYPE, dtype: object

# %%
df.loc[0:3, ['NAME_CONTRACT_TYPE','TARGET']]
# Out:
#   NAME_CONTRACT_TYPE  TARGET
# 0         Cash loans       1
# 1         Cash loans       0
# 2    Revolving loans       0
# 3         Cash loans       0

# %%
df.loc[axis=1,['NAME_CONTRACT_TYPE','TARGET']]
# Out:
#   File "<ipython-input-13-bcb95b3eb100>", line 1
#     df.loc[axis=1,['NAME_CONTRACT_TYPE','TARGET']]
#                ^
# SyntaxError: invalid syntax

# %%
df.loc[1:3,'TARGET' : 'FLAG_OWN_CAR']
# Out:
#    TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR
# 1       0         Cash loans           F            N
# 2       0    Revolving loans           M            Y
# 3       0         Cash loans           F            N

# %%
df.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#               ...              FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# ...

# %%
df.iloc[1:2,1:3]
# Out:
#    TARGET NAME_CONTRACT_TYPE
# 1       0         Cash loans

# %%
df.ix[1, 0]
# Out:
# C:\Users\Vikash\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 100003

# %%
df.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#               ...              FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# ...

# %%
df.loc[1,'SK_ID_CURR']
# Out:
# 100003

# %%
df.set_index('NAME_CONTRACT_TYPE',inplace=True)

# %%
df.head()
# Out:
#                     SK_ID_CURR  TARGET CODE_GENDER FLAG_OWN_CAR  \
# NAME_CONTRACT_TYPE
# Cash loans              100002       1           M            N
# Cash loans              100003       0           F            N
# Revolving loans         100004       0           M            Y
# Cash loans              100006       0           F            N
# Cash loans              100007       0           M            N
#
#                    FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# NAME_CONTRACT_TYPE
# Cash loans                       Y             0          202500.0
# Cash loans                       N             0          270000.0
# Revolving loans                  Y             0           67500.0
# Cash loans                       Y             0          135000.0
# Cash loans                       Y             0          121500.0
#
#                     AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# NAME_CONTRACT_TYPE
# ...

# %%
df.ix[0:1,0]
# Out:
# C:\Users\Vikash\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# NAME_CONTRACT_TYPE
# Cash loans    100002
# Name: SK_ID_CURR, dtype: int64

# %%
df.reset_index(inplace=True)

# %%
df.ix[0:2,0]
# Out:
# C:\Users\Vikash\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 0         Cash loans
# 1         Cash loans
# 2    Revolving loans
# Name: NAME_CONTRACT_TYPE, dtype: object

# %%
df
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0           100002       1         Cash loans           M            N
# 1           100003       0         Cash loans           F            N
# 2           100004       0    Revolving loans           M            Y
# 3           100006       0         Cash loans           F            N
# 4           100007       0         Cash loans           M            N
# 5           100008       0         Cash loans           M            N
# 6           100009       0         Cash loans           F            Y
# 7           100010       0         Cash loans           M            Y
# 8           100011       0         Cash loans           F            N
# 9           100012       0    Revolving loans           M            N
# 10          100014       0         Cash loans           F            N
# 11          100015       0         Cash loans           F            N
# ...

# %%
df.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER',
#        'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL',
#        'AMT_CREDIT', 'AMT_ANNUITY',
#        ...
#        'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20',
#        'FLAG_DOCUMENT_21', 'AMT_REQ_CREDIT_BUREAU_HOUR',
#        'AMT_REQ_CREDIT_BUREAU_DAY', 'AMT_REQ_CREDIT_BUREAU_WEEK',
#        'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT',
#        'AMT_REQ_CREDIT_BUREAU_YEAR'],
#       dtype='object', length=122)
