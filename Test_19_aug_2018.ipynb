# %%
import pandas as pd
df=pd.read_excel('C:\\Users\\29265\\Desktop\\data.xlsx',sheetname='Sheet6')

# %%
from scipy import stats
import numpy as np
df[(np.abs(stats.zscore(df)) < 3).all(axis=1)]
# Out:
#    sales  units  trans
# 0      2      4      6
# 1      1      3      6
# 2      4      3      7
# 3      7      2      4
# 4      6      5      5
# 5     23     45     23
# 6     89     90     56
# 7   2000   2100   1000

# %%
def remove_outlier(df_in):
    for i in df.columns:
        
        q1 = df_in[i].quantile(0.25)
        q3 = df_in[i].quantile(0.75)
        iqr = q3-q1 #Interquartile range
        fence_low  = q1-1.5*iqr
        fence_high = q3+1.5*iqr
        df_out = df_in.loc[(df_in[i] > fence_low) & (df_in[i] < fence_high)]
    return df_out

# %%
df=remove_outlier(df)

# %%
df
# Out:
#    sales  units  trans
# 0      2      4      6
# 1      1      3      6
# 2      4      3      7
# 3      7      2      4
# 4      6      5      5
# 5     23     45     23
# 6     89     90     56

# %%
for i in range(0, 5):
    for j in range(5, i, -1):
        print("* ", end="")
    print()
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
df['sales'].median()
# Out:
# 6.0

# %%
df=df.corr()
df
# Out:
#           sales     units     trans
# sales  1.000000  0.999939  0.999934
# units  0.999939  1.000000  0.999946
# trans  0.999934  0.999946  1.000000

# %%
a=list(df.corr().abs().unstack()> 0.5)
df[a[2]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\29265\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20405)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20359)()
#
# KeyError: True
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
for i in df.columns:
    if -1<df[i] & df[i] >-0.8:
        print (df[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\29265\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     882         try:
# --> 883             result = op(x, y)
#     884         except TypeError:
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-cf643d6e4840> in <module>()
#       1 for i in df.columns:
# ----> 2     if -1<df[i] & df[i] >-0.8:
#       3         print (df[i])
#
# C:\Users\29265\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(self, other)
# ...

# %%
def compute( a, b) :
    AM = (a + b) / 2
    GM = math.sqrt(a * b)
    HM = (GM * GM) / AM
    return HM

# %%
df
# Out:
#    sales  units  trans
# 0      2      4      6
# 1      1      3      6
# 2      4      3      7
# 3      7      2      4
# 4      6      5      5
# 5     23     45     23
# 6     89     90     56
# 7   2000   2100   1000

# %%
df.shape[0]
# Out:
# 8

# %%
AM=df['sales'].sum()/df.shape[0]

# %%
import math
GM=math.sqrt(df['sales'].prod())

# %%
GM
# Out:
# 37088.866253904285

# %%
HM=(GM * GM) / AM

# %%
HM
# Out:
# 5161666.041275797

# %%
p=''
for i in range(0,4):
    for j in range(0,i):
        p=p+a
        if(len(p)==6):
            break
        print (p+'$'+p)
        print()
# Out:
# a$a
#
# aa$aa
#
# aaa$aaa
#
# aaaa$aaaa
#
# aaaaa$aaaaa

# %%
add = lambda x, y : x + y 
add(2,3)
# Out:
# 5

# %%
type(add)
# Out:
# function
