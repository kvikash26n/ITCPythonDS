# %%
import keyword
print (keyword.kwlist)
len(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 33

# %%
import numpy as np
lis=[1,3,5,'']
print (type(lis[0]))
nplis=np.array(lis)
print (nplis)
print (nplis[0])
#print (nplis)
print (type(nplis[0]))
# Out:
# <class 'int'>
# ['1' '3' '5' '']
# 1
# <class 'numpy.str_'>

# %%
P=100
n=100
r=10
t=7
a=P*pow((1+r/n),7)
print(a)
# Out:
# 194.87171000000012

# %%
print (2//3)
# Out:
# 0

# %%
r=5
pie=3.14
print(2*pie*r)
print(pie*r**2)
# Out:
# 31.400000000000002
# 78.5

# %%
str='1234'
str='6789'
print (str[1])
# Out:
# 7

# %%
a=[1,2,3,4,'satyam']
a[5]=8787
print (a[1:])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-36-62909fee2c20> in <module>()
#       1 a=[1,2,3,4,'satyam']
# ----> 2 a[5]=8787
#       3 print (a[1:])
#
# IndexError: list assignment index out of range

# %%
tuples=(1,2,3)
'''
jhkjuikuyikukli
'''
'''tuples[1]=6'''
''''''
print (tuples)
# Out:
# (1, 2, 3)

# %%
d={'a':1,'b':2}
print (d.keys())
d['a']
print (d.values())
# Out:
# dict_keys(['a', 'b'])
# dict_values([1, 2])
