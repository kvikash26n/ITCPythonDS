# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
a="dATA SCIENCE"
a.capitalize()
a.center(20,'a')
a.count('AT',0,6)
# Out:
# 'Data science'
# 'aaaadATA SCIENCEaaaa'
# 1

# %%
a='vikash'
b=a.encode('UTF-16')
print (b)
b.decode('UTF-16')
# Out:
# b'\xff\xfev\x00i\x00k\x00a\x00s\x00h\x00'
# 'vikash'

# %%
def diff():
    import numpy as np
    import pandas as pd

    xld=pd.ExcelFile('C:\\Users\\29265\\Desktop\\pythonAssignment.xlsx')
    d1= pd.read_excel(xld,'Sheet1')
    d2 = pd.read_excel(xld,'Sheet2')

    diff1=[]
    diff2=[]

    for row in range(d1.shape[0]):
        for col in range(d2.shape[1]):
            d1_data=d1.iloc[row,col]
            d2_data=d2.iloc[row,col]
            if d1_data==d2_data:
                pass
            else:
                diff1.append(d1_data)
                diff2.append(d2_data)
    
    
    sd1=pd.DataFrame(diff1)
    sd2=pd.DataFrame(diff2)
    #print('d2 data not in d1 {}'.format(sd1))
    #print('d1 data not in d2 {}'.format(sd2))
    #return diff1
    xldr='D:/diff_xls.xlsx'
    writer = pd.ExcelWriter(xldr, engine='xlsxwriter')
    sd1.to_excel(writer, sheet_name='not in d1')
    sd2.to_excel(writer, sheet_name='not in d2')

    workbook = writer.book
    worksheet = writer.sheets['not in d1']
    worksheet = writer.sheets['not in d2']

if __name__=='__main__':
    diff()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-979184a68e02> in <module>()
#      36
#      37 if __name__=='__main__':
# ---> 38     diff()
#
# <ipython-input-2-979184a68e02> in diff()
#      13         for col in range(d2.shape[1]):
#      14             d1_data=d1.iloc[row,col]
# ---> 15             d2_data=d2.iloc[row,col]
#      16             if d1_data==d2_data:
#      17                 pass
#
# C:\Users\29265\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1323             except (KeyError, IndexError):
#    1324                 pass
# -> 1325             return self._getitem_tuple(key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
#
# ...

# %%
a='Datas science'
print(a.find('Data',0,6))
a.index('at',0,6)
a.endswith('e')
a.expandtabs(tabsize=11)
for i in a.split():
  #  i[0].capitalize()
    
    print(i[0:4].capitalize()+i[4].capitalize())
# Out:
# 0
# DataS
# ScieN

# %%
a=input()
print (a)

b={int(input())}
print (b)

# %%
a=input()
print (a)

b={int(input())}
print (b)

# %%
b=int(input())
print ({int(input())})
'''
try:
    while({int(input())}):
          print ("entered the data suecfully")
except ValueError:
     print("no valid number.  Try again.")
'''

# %%
 while({int(input())}):
          print ("entered the data suecfully")
            continue

# %%
a='vikash'
for i in a:
    print(i)
# Out:
# v
# i
# k
# a
# s
# h

# %%
a=20
while(a>10):
    print(a)
    a=a-1
# Out:
# 20
# 19
# 18
# 17
# 16
# 15
# 14
# 13
# 12
# 11

# %%
a=[1,3,5]
describe(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-496f16dab9e6> in <module>()
#       1 a=[1,3,5]
# ----> 2 describe(a)
#
# NameError: name 'describe' is not defined
