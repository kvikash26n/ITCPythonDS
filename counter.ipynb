# %%
from collections import Counter
a=Counter([2,2,3,4])

# %%
f=open('abc.txt')
a=f.read()
a=Counter(a.split())
a
# Out:
# Counter({'a': 2,
#          'is': 1,
#          'kumar': 2,
#          'ram': 1,
#          'shyam': 1,
#          'the': 1,
#          'vikash': 2})

# %%
a['kumar']
# Out:
# 2

# %%
data=[]
for i in a:
    datadic={
        'key':i,
        'val':a[i]
    }
    data.append(datadic)
data
# Out:
# [{'key': 'kumar', 'val': 2},
#  {'key': 'vikash', 'val': 2},
#  {'key': 'ram', 'val': 1},
#  {'key': 'shyam', 'val': 1},
#  {'key': 'the', 'val': 1},
#  {'key': 'is', 'val': 1},
#  {'key': 'a', 'val': 2}]

# %%
import pandas as pd
pd.DataFrame(data,columns=['key','val'])
# Out:
#       key  val
# 0   kumar    2
# 1  vikash    2
# 2     ram    1
# 3   shyam    1
# 4     the    1
# 5      is    1
# 6       a    2

# %%
key=list(a.keys())
key
val=list(a.values())
val
# Out:
# [2, 1, 1]
