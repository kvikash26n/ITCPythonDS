# %%
#to create file like text/doc/ppt/csv/excel
# %%writefile text12.doc
this is my f file
# Out:
#   File "<ipython-input-58-7fa73a77b9e2>", line 2
#     %%writefile text12.doc
#     ^
# SyntaxError: invalid syntax

# %%
pwd
# Out:
# 'C:\\Users\\Vikash'

# %%
#to open the file
f=open('text12.txt')
f.read()
# Out:
# 'tetstwtrrddtetstwtrrdd\n tetstwtrrdd'

# %%
f.read()
# Out:
# ''

# %%
#to bring it back to cursor at zero place
f.seek(0)
f.read()
# Out:
# 'this is my f file\nthis is\n\neterfge'

# %%
#will create every line as list elements
f.seek(0)
a=f.readlines()

# %%
a.split()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-d951bd4a63fe> in <module>()
# ----> 1 a.split()
#
# AttributeError: 'list' object has no attribute 'split'

# %%
frea
# Out:
# <_io.TextIOWrapper name='text12.txt' mode='r' encoding='cp1252'>

# %%
b=[]
for i in a:
     a= i.split(" ")
     b.append(a)

# %%
b
# Out:
# [['this', 'is', 'my', 'f', 'file\n'], ['this', 'is\n'], ['\n'], ['eterfge']]

# %%
f.seek(0)
a=f.read()
a=a.split()

# %%
b=[]
for i in a:
    b.append(i)

# %%
b
# Out:
# ['this', 'is', 'my', 'f', 'file', 'this', 'is', 'eterfge']

# %%
len(b)
# Out:
# 8

# %%
#count each elemnt using for loop
for i in len(b):

# %%
import pandas as pd
df=pd.DataFrame(b)

# %%
df
# Out:
#          0
# 0     this
# 1       is
# 2       my
# 3        f
# 4     file
# 5     this
# 6       is
# 7  eterfge

# %%
df[0].value_counts()
# Out:
# this       2
# is         2
# file       1
# f          1
# my         1
# eterfge    1
# Name: 0, dtype: int64

# %%
df.count()
df.describe
# Out:
# <bound method NDFrame.describe of          0
# 0     this
# 1       is
# 2       my
# 3        f
# 4     file
# 5     this
# 6       is
# 7  eterfge>

# %%
# os file checking
import os
os.listdir("C:\\")
# Out:
# ['$Recycle.Bin',
#  '100CANON',
#  'autoexec.bat',
#  'Config.Msi',
#  'config.sys',
#  'cucu',
#  'Documents and Settings',
#  'ESD',
#  'hiberfil.sys',
#  'inetpub',
#  'Intel',
#  'IO.SYS',
#  'MSDOS.SYS',
#  'MSOCache',
#  'pagefile.sys',
#  'PerfLogs',
#  'Program Files',
#  'ProgramData',
#  'project',
#  'Recovery',
#  'rtrC170.tmp',
#  'Ruby23',
#  'swapfile.sys',
#  'System Volume Information',
#  'Users',
#  'Windows',
#  '[Smad-Cage]']

# %%
# to get all file with specified format
import glob
glob.glob("C:\\Users\\Vikash\\Downloads\\*.html")
# Out:
# ['C:\\Users\\Vikash\\Downloads\\8_INV-KA171021562488-102012611038-DECEMBER-2017.html',
#  'C:\\Users\\Vikash\\Downloads\\Args and kwargs.html',
#  'C:\\Users\\Vikash\\Downloads\\Pandas Advanced Concepts_Session 2 (1).html',
#  'C:\\Users\\Vikash\\Downloads\\Seaborn 100 Graphs Challenge - Notebook 2 (1).html',
#  'C:\\Users\\Vikash\\Downloads\\Seaborn 100 Graphs Challenge - Notebook 2.html']

# %%
#problem to read all csv file from some particular loc ation n read thenm/describing them
#x='C:\\Users\\Vikash\\Downloads\\*.'
#y=input()
allfile=glob.glob("C:\\Users\\Vikash\\Downloads\\*.csv")
for i in allfile:
    df=pd.read_csv(i)
   # percent = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending = False)
    #print(percent)
    print(df.describe())
    print("**************")
# Out:
# COMMONAREA_MEDI                69.872297
# COMMONAREA_AVG                 69.872297
# COMMONAREA_MODE                69.872297
# NONLIVINGAPARTMENTS_MODE       69.432963
# NONLIVINGAPARTMENTS_MEDI       69.432963
# NONLIVINGAPARTMENTS_AVG        69.432963
# FONDKAPREMONT_MODE             68.386172
# LIVINGAPARTMENTS_MEDI          68.354953
# LIVINGAPARTMENTS_MODE          68.354953
# LIVINGAPARTMENTS_AVG           68.354953
# FLOORSMIN_MEDI                 67.848630
# FLOORSMIN_MODE                 67.848630
# FLOORSMIN_AVG                  67.848630
# YEARS_BUILD_MEDI               66.497784
# YEARS_BUILD_AVG                66.497784
# YEARS_BUILD_MODE               66.497784
# OWN_CAR_AGE                    65.990810
# LANDAREA_MODE                  59.376738
# LANDAREA_AVG                   59.376738
# LANDAREA_MEDI                  59.376738
# BASEMENTAREA_MEDI              58.515956
# BASEMENTAREA_AVG               58.515956
# BASEMENTAREA_MODE              58.515956
# ...

# %%
# same program with user inputs
#x='C:\\Users\\Vikash\\Downloads\\*.'
x=input()
y=input()
allfile=glob.glob(x+y)
for i in allfile:
    df=pd.read_csv(i)
    print(df.describe())
    print("**************")
# Out:
# C:\\Users\\Vikash\\Downloads\\*.
# xlsx
#         Vikash
# count                                                   0
# unique                                                  0
# **************
#         Vikash
# count                                                   0
# unique                                                  0
# **************

# %%
#problem to read all csv file from some particular loc ation n read thenm/describing them
#x='C:\\Users\\Vikash\\Downloads\\*.'
#y=input()
#to print null value percent
allfile=glob.glob("C:\\Users\\Vikash\\Downloads\\*.csv")
for i in allfile:
    df=pd.read_csv(i)
    percent = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending = False)
    print(percent)
    #print(df.describe())
    print("**************")
# Out:
# COMMONAREA_MEDI                69.872297
# COMMONAREA_AVG                 69.872297
# COMMONAREA_MODE                69.872297
# NONLIVINGAPARTMENTS_MODE       69.432963
# NONLIVINGAPARTMENTS_MEDI       69.432963
# NONLIVINGAPARTMENTS_AVG        69.432963
# FONDKAPREMONT_MODE             68.386172
# LIVINGAPARTMENTS_MEDI          68.354953
# LIVINGAPARTMENTS_MODE          68.354953
# LIVINGAPARTMENTS_AVG           68.354953
# FLOORSMIN_MEDI                 67.848630
# FLOORSMIN_MODE                 67.848630
# FLOORSMIN_AVG                  67.848630
# YEARS_BUILD_MEDI               66.497784
# YEARS_BUILD_AVG                66.497784
# YEARS_BUILD_MODE               66.497784
# OWN_CAR_AGE                    65.990810
# LANDAREA_MODE                  59.376738
# LANDAREA_AVG                   59.376738
# LANDAREA_MEDI                  59.376738
# BASEMENTAREA_MEDI              58.515956
# BASEMENTAREA_AVG               58.515956
# BASEMENTAREA_MODE              58.515956
# ...

# %%
allfile=glob.glob("C:\\Users\\Vikash\\Downloads\\*.csv")
for i in allfile:
    df=pd.read_csv(i)
    percent = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending = False)
    print(percent)
    df.shape()
    #print(df.describe())
    print("**************")

# %%
allcol=list(df.columns)
allcol
# Out:
# ['Year',
#  'Datetime',
#  'Stage',
#  'Stadium',
#  'City',
#  'Home Team Name',
#  'Home Team Goals',
#  'Away Team Goals',
#  'Away Team Name',
#  'Win conditions',
#  'Attendance',
#  'Half-time Home Goals',
#  'Half-time Away Goals',
#  'Referee',
#  'Assistant 1',
#  'Assistant 2',
#  'RoundID',
#  'MatchID',
#  'Home Team Initials',
#  'Away Team Initials']
