# %%
def test1(x,y):
    
    print("this is test")
    return(x*y)

# %%
a=test1(3,4)
# Out:
# this is test

# %%
a
# Out:
# 12

# %%
def test1():
    print("this is test")
test1()
# Out:
# this is test

# %%
def f1(x):
    print("1st")
def f2():
    print("dghdg")
def f3():
    print ("gfd")
    if(x==2):
        return f2()
    else:
        return f3()
f1(2)
# Out:
# 1st

# %%
def A():
    print('This is A method')
def B(A):
    print("this is B method")
    A()
B(A)
# Out:
# this is B method
# This is A method

# %%
a=lambda i,p:(i*i)/p
a(2,4)
# Out:
# 1.0

# %%
lambda str:str[0]
# Out:
# <function __main__.<lambda>(str)>

# %%
a=lambda str:str[0]

# %%
a(input())
# Out:
# 23
# '2'

# %%
lambda str:str[0]
# Out:
# <function __main__.<lambda>(str)>

# %%
def ff(x,y):
    lambda x,y:x*y
ff(2,3)

# %%
list(map(lambda x:x*2,[2,1,3]))
# Out:
# [4, 2, 6]

# %%
list(filter(lambda x:True if x%2==0 else False ,[1,2,4,5,6]))
# Out:
# [2, 4, 6]

# %%
a=lambda x:True if x%2==0 else False

# %%
a(2)
# Out:
# True

# %%
def a(x):
    if(x%2==0):
        return True
    else:
        return False
list(filter(a,[1,2,3,4,5,6]))
# Out:
# [2, 4, 6]

# %%
from functools import reduce as rd
rd(lambda x,y:x if x>y else y ,[1,2,3,4,5])
# Out:
# 5

# %%
lambda x,y:x if x>y else y
# Out:
# <function __main__.<lambda>(x, y)>
