# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\29265\\Desktop\\\house\\train.csv")
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df['const']=1

# %%
df.fillna(1,inplace=True)
df=df[df.describe().columns]

# %%
y=df['SalePrice']

# %%
x=df.drop('SalePrice',axis=1)

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 100)

# %%
import statsmodels.api as sm
import statsmodels.formula.api as sfa

# %%
 
model=sm.OLS(y_train,x_train)

# %%
model=sm.OLS(y_train,x_train) 
lm=model.fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.807
# Model:                            OLS   Adj. R-squared:                  0.801
# Method:                 Least Squares   F-statistic:                     135.2
# Date:                Sat, 29 Sep 2018   Prob (F-statistic):               0.00
# Time:                        11:09:02   Log-Likelihood:                -13872.
# No. Observations:                1168   AIC:                         2.782e+04
# Df Residuals:                    1132   BIC:                         2.800e+04
# Df Model:                          35
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
lm.rsquared
# Out:
# 0.80700156229829545

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice', 'const'],
#       dtype='object')

# %%
lt=list(df['MSSubClass'])

# %%
import numpy as np
print(np.var(lt))
# Out:
# 1788.11273222

# %%
frame=[]
for i in df.columns:
    lt=list(df[i])
    a=np.var(lt)
    #data={i:a}
    frame.append(a)
frame  
tab=pd.DataFrame(frame,index=df.columns)
#tab.sort_values
#tab.sort_values([0])

# %%
tab
# Out:
#                           0
# Id             1.776332e+05
# MSSubClass     1.788113e+03
# LotFrontage    1.180492e+03
# LotArea        9.955741e+07
# OverallQual    1.911369e+00
# OverallCond    1.237474e+00
# YearBuilt      9.115906e+02
# YearRemodAdd   4.259409e+02
# MasVnrArea     3.264033e+04
# BsmtFinSF1     2.078830e+05
# BsmtFinSF2     2.600608e+04
# BsmtUnfSF      1.951127e+05
# TotalBsmtSF    1.923305e+05
# 1stFlrSF       1.493477e+05
# 2ndFlrSF       1.904266e+05
# LowQualFinSF   2.362585e+03
# GrLivArea      2.759405e+05
# BsmtFullBath   2.690838e-01
# BsmtHalfBath   5.696378e-02
# FullBath       3.033003e-01
# HalfBath       2.527205e-01
# BedroomAbvGr   6.650380e-01
# KitchenAbvGr   4.851567e-02
# TotRmsAbvGrd   2.640094e+00
# Fireplaces     4.153101e-01
# GarageYrBlt    2.054929e+05
# GarageCars     5.580972e-01
# GarageArea     4.568120e+04
# WoodDeckSF     1.569905e+04
# OpenPorchSF    4.386854e+03
# EnclosedPorch  3.732992e+03
# 3SsnPorch      8.589172e+02
# ...

# %%
tab[0].sort_values(ascending=False)
# Out:
# SalePrice        6.306789e+09
# LotArea          9.955741e+07
# GrLivArea        2.759405e+05
# MiscVal          2.459695e+05
# BsmtFinSF1       2.078830e+05
# GarageYrBlt      2.054929e+05
# BsmtUnfSF        1.951127e+05
# TotalBsmtSF      1.923305e+05
# 2ndFlrSF         1.904266e+05
# Id               1.776332e+05
# 1stFlrSF         1.493477e+05
# GarageArea       4.568120e+04
# MasVnrArea       3.264033e+04
# BsmtFinSF2       2.600608e+04
# WoodDeckSF       1.569905e+04
# OpenPorchSF      4.386854e+03
# EnclosedPorch    3.732992e+03
# ScreenPorch      3.106760e+03
# LowQualFinSF     2.362585e+03
# MSSubClass       1.788113e+03
# PoolArea         1.613110e+03
# LotFrontage      1.180492e+03
# YearBuilt        9.115906e+02
# 3SsnPorch        8.589172e+02
# YearRemodAdd     4.259409e+02
# MoSold           7.304588e+00
# TotRmsAbvGrd     2.640094e+00
# OverallQual      1.911369e+00
# YrSold           1.762629e+00
# OverallCond      1.237474e+00
# BedroomAbvGr     6.650380e-01
# ...

# %%
col=list(tab.tail(5).index)
col
df.drop(col,axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea'],
#       dtype='object')

# %%
for i in df.columns:
    p=pd.DataFrame(df[i])
    
   # c=dff.i
    #c[]
    model=sm.OLS(y_train,p) 
    lm=model.fit()
    lm.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-5593ba6ab64d> in <module>()
#       4    # c=dff.i
#       5     #c[]
# ----> 6     model=sm.OLS(y_train,p)
#       7     lm=model.fit()
#       8     lm.summary()
#
# C:\Users\29265\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     629                  **kwargs):
#     630         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 631                                   hasconst=hasconst, **kwargs)
#     632         if "weights" in self._init_keys:
#     633             self._init_keys.remove("weights")
#
# C:\Users\29265\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
# ...

# %%
p.shape

# %%
a=[1,3,2]

q=pd.DataFrame(a)
q[0].sort_values(ascending=False)
# Out:
# 1    3
# 2    2
# 0    1
# Name: 0, dtype: int64

# %%
p.shape

# %%
#y_train.shape
#for i in df.columns:
    
#df.loc[0:3, ['NAME_CONTRACT_TYPE','TARGET']]

for i in df.columns:
    print(df.iloc[0:,[range([i])])
#df.loc[0:3, ['Id']]
# Out:
#   File "<ipython-input-54-9eae86da5dbf>", line 7
#     print(df.iloc[0:,[range([i])])
#                                  ^
# SyntaxError: invalid syntax

# %%
df.head()

# %%
#to get df with coloumns name one by one
a=[]
for i in df.columns:
    a.append(i)
    print(df.loc[0:,a])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-dc770d7c0d12> in <module>()
#       3 for i in df.columns:
#       4     a.append(i)
# ----> 5     print(df.loc[0:,a])
#
# C:\Users\29265\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1323             except (KeyError, IndexError):
#    1324                 pass
# -> 1325             return self._getitem_tuple(key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
#
# C:\Users\29265\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     854                 continue
#     855
# --> 856             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     857
#     858         return retval
#
# ...

# %%
b=[]
for i in df.columns:
    dic={
        i:df[i]
        
    }
    b.append(dic)
    dff=pd.DataFrame(b)
    print(dff.head(2))
# Out:
#                                                    0
# 0  Id                  -0.204758
# MSSubClass      ...

# %%
p=pd.DataFrame(df['Id'])
    
   # c=dff.i
    #c[]
model=sm.OLS(y_train,p) 
lm=model.fit()
lm.summary()

# %%
p=pd.DataFrame(df.iloc[0:,0])
p

# %%
p=pd.DataFrame(df['Id'])
p.head()
# Out:
#    Id
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5

# %%
#df.GarageArea
p=pd.DataFrame(df['GarageArea'])

# %%
x_train_v1=x_train
x_test_v1=x_test
y_train_v1=y_train
y_test_v1=y_test

# %%
y_train_v1
# Out:
# 133     220000
# 290     233230
# 24      154000
# 1093    146000
# 1288    278000
# 374     219500
# 562     108000
# 529     200624
# 1359    315000
# 447     199900
# 1048    115000
# 1345    108500
# 1424    144000
# 1132    117500
# 893     165000
# 945     124900
# 1122    112000
# 980     178400
# 526     132000
# 48      113000
# 463     188700
# 1140    139000
# 1396    160000
# 646      98300
# 110     136900
# 198     104000
# 67      226000
# 1335    167900
# 667     193500
# 108     115000
#          ...
# 2       223500
# 1360    189000
# 763     337000
# 967     135000
# 782     187100
# 317     270000
# 49      127000
# 135     174000
# 835     128000
# 603     151000
# 1028    105000
# 612     261500
# 757     158900
# 1165    233170
# 897     142953
# 415     181134
# 386      81000
# 86      174000
# 1117    130000
# 912      88000
# 1340    123000
# 1252    130000
# 280     228500
# 752     217000
# 1009    102000
# 802     189000
# 53      385000
# ...

# %%
model=sm.OLS(y_train_v1,x_train) 
lm=model.fit()
lm.summary()
 lm.co
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.807
# Model:                            OLS   Adj. R-squared:                  0.801
# Method:                 Least Squares   F-statistic:                     135.2
# Date:                Sat, 11 Aug 2018   Prob (F-statistic):               0.00
# Time:                        09:33:41   Log-Likelihood:                -13872.
# No. Observations:                1168   AIC:                         2.782e+04
# Df Residuals:                    1132   BIC:                         2.800e+04
# Df Model:                          35
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
x_train.head()
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 133    134          20          0.0     6853            8            5
# 290    291          60        120.0    15611            8            5
# 24      25          20          0.0     8246            5            8
# 1093  1094          20         71.0     9230            5            8
# 1288  1289         120         40.0     5664            8            5
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...    WoodDeckSF  \
# 133        2001          2002       136.0        1005  ...           192
# 290        2006          2006         0.0           0  ...             0
# 24         1968          2001         0.0         188  ...           406
# 1093       1965          1998       166.0         661  ...             0
# 1288       2000          2000         0.0        1158  ...           212
#
#       OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# ...

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm = lm.fit(x_train,y_train)   #lm.fit(input,output)
lm.coef_
# Out:
# array([ -2.04758170e-01,  -1.78879275e+02,   8.50094766e+00,
#          3.22536481e-01,   1.71078282e+04,   4.99507638e+03,
#          3.38022567e+02,   1.50432936e+02,   3.24764525e+01,
#          8.39887896e+00,   6.57946227e-01,   5.13272694e-02,
#          9.10815245e+00,   1.94162796e+01,   2.16346855e+01,
#         -1.36006396e+01,   2.74503254e+01,   1.21190959e+04,
#          4.13421912e+03,   3.26954699e+03,  -8.20866391e+02,
#         -9.86463216e+03,  -1.26684176e+04,   3.96296272e+03,
#          5.52597933e+03,  -1.51805908e+01,   1.61110444e+04,
#          2.78580260e+00,   1.85227190e+01,  -1.72600954e+01,
#          1.07954882e+01,   3.52531160e+01,   3.78416097e+01,
#         -8.40990391e+01,  -1.90942831e-01,  -1.06373893e+02,
#         -9.24524991e+02,   0.00000000e+00])

# %%
df=pd.DataFrame(lm.coef_,index=x_train.columns)

# %%
df[0].sort_values()
# Out:
# KitchenAbvGr    -12668.417628
# BedroomAbvGr     -9864.632156
# YrSold            -924.524991
# HalfBath          -820.866391
# MSSubClass        -178.879275
# MoSold            -106.373893
# PoolArea           -84.099039
# OpenPorchSF        -17.260095
# GarageYrBlt        -15.180591
# LowQualFinSF       -13.600640
# Id                  -0.204758
# MiscVal             -0.190943
# const                0.000000
# BsmtUnfSF            0.051327
# LotArea              0.322536
# BsmtFinSF2           0.657946
# GarageArea           2.785803
# BsmtFinSF1           8.398879
# LotFrontage          8.500948
# TotalBsmtSF          9.108152
# EnclosedPorch       10.795488
# WoodDeckSF          18.522719
# 1stFlrSF            19.416280
# 2ndFlrSF            21.634685
# GrLivArea           27.450325
# MasVnrArea          32.476452
# 3SsnPorch           35.253116
# ScreenPorch         37.841610
# YearRemodAdd       150.432936
# YearBuilt          338.022567
# FullBath          3269.546991
# ...

# %%
import matplotlib.pyplot as pt

pt.plot(lm.coef_,color='g')
#pt.xlabel('sales')
#pt.ylabel('count')
pt.show()

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\29265\\Downloads\\\house\\Train_Dataset.csv")
df
