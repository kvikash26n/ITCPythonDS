# %%
import pandas as pd
from sklearn import preprocessing
import pandas as pd
df=pd.read_csv("C:\\Users\\29265\\Downloads\\train.csv")
#data = {'score': [234,24,14,27,-74,46,73,-18,59,160]}
#df1 = pd.DataFrame(data)
#df1

min_max_scaler = preprocessing.MinMaxScaler()
np_scaled = min_max_scaler.fit_transform(df)
df_normalized = pd.DataFrame(np_scaled)
df_normalized
# Out:
# C:\Users\29265\AppData\Local\Continuum\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-2f1104e39454> in <module>()
#       8
#       9 min_max_scaler = preprocessing.MinMaxScaler()
# ---> 10 np_scaled = min_max_scaler.fit_transform(df)
#      11 df_normalized = pd.DataFrame(np_scaled)
#      12 df_normalized
#
# C:\Users\29265\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     492         if y is None:
#     493             # fit method of arity 1 (unsupervised transformation)
# --> 494             return self.fit(X, **fit_params).transform(X)
# ...

# %%
df1=df.loc[0:,['Store','Customers']]

pd.rename(df1,columns={'0':'s','1':'p'})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-0c8369cf269f> in <module>()
#       1 df1=df.loc[0:,['Store','Customers']]
# ----> 2 pd.rename(df1,columns={'0':'s','1':'p'})
#
# AttributeError: module 'pandas' has no attribute 'rename'

# %%
df1.rename(columns={'0':'s','1':'p'},inplace=True)

# %%
df1
# Out:
#          Store  Customers
# 0            1        555
# 1            2        625
# 2            3        821
# 3            4       1498
# 4            5        559
# 5            6        589
# 6            7       1414
# 7            8        833
# 8            9        687
# 9           10        681
# 10          11       1236
# 11          12        962
# 12          13        568
# 13          14        710
# 14          15        766
# 15          16        979
# 16          17        946
# 17          18        936
# 18          19        718
# 19          20        974
# 20          21        682
# 21          22        633
# 22          23        560
# 23          24       1082
# 24          25       1586
# 25          26        611
# 26          27       1263
# 27          28        663
# 28          29        737
# 29          30        625
# ...        ...        ...
# 1017179   1086          0
# 1017180   1087          0
# 1017181   1088          0
# ...

# %%
df
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# 5            6          5  2015-07-31   5651        589     1      1
# 6            7          5  2015-07-31  15344       1414     1      1
# 7            8          5  2015-07-31   8492        833     1      1
# 8            9          5  2015-07-31   8565        687     1      1
# 9           10          5  2015-07-31   7185        681     1      1
# 10          11          5  2015-07-31  10457       1236     1      1
# 11          12          5  2015-07-31   8959        962     1      1
# 12          13          5  2015-07-31   8821        568     1      1
# ...

# %%
df1
min_max_scaler = preprocessing.MinMaxScaler()
np_scaled = min_max_scaler.fit_transform(df1)
df_normalized = pd.DataFrame(np_scaled)
df_normalized
# Out:
#                 0         1
# 0        0.000000  0.075122
# 1        0.000898  0.084597
# 2        0.001795  0.111126
# 3        0.002693  0.202761
# 4        0.003591  0.075663
# 5        0.004488  0.079724
# 6        0.005386  0.191391
# 7        0.006284  0.112750
# 8        0.007181  0.092989
# 9        0.008079  0.092177
# 10       0.008977  0.167298
# 11       0.009874  0.130211
# 12       0.010772  0.076881
# 13       0.011670  0.096102
# 14       0.012567  0.103682
# 15       0.013465  0.132512
# 16       0.014363  0.128045
# 17       0.015260  0.126692
# 18       0.016158  0.097185
# 19       0.017056  0.131835
# 20       0.017953  0.092312
# 21       0.018851  0.085679
# 22       0.019749  0.075799
# 23       0.020646  0.146454
# 24       0.021544  0.214672
# 25       0.022442  0.082702
# 26       0.023339  0.170953
# 27       0.024237  0.089740
# 28       0.025135  0.099756
# 29       0.026032  0.084597
# ...           ...       ...
# 1017179  0.973968  0.000000
# ...

# %%
min_max_scaler = preprocessing.MinMaxScaler()
np_scaled = min_max_scaler.fit_transform(df1[df1.columns])
df_normalized = pd.DataFrame(np_scaled)
df_normalized
# Out:
#                 0         1
# 0        0.000000  0.075122
# 1        0.000898  0.084597
# 2        0.001795  0.111126
# 3        0.002693  0.202761
# 4        0.003591  0.075663
# 5        0.004488  0.079724
# 6        0.005386  0.191391
# 7        0.006284  0.112750
# 8        0.007181  0.092989
# 9        0.008079  0.092177
# 10       0.008977  0.167298
# 11       0.009874  0.130211
# 12       0.010772  0.076881
# 13       0.011670  0.096102
# 14       0.012567  0.103682
# 15       0.013465  0.132512
# 16       0.014363  0.128045
# 17       0.015260  0.126692
# 18       0.016158  0.097185
# 19       0.017056  0.131835
# 20       0.017953  0.092312
# 21       0.018851  0.085679
# 22       0.019749  0.075799
# 23       0.020646  0.146454
# 24       0.021544  0.214672
# 25       0.022442  0.082702
# 26       0.023339  0.170953
# 27       0.024237  0.089740
# 28       0.025135  0.099756
# 29       0.026032  0.084597
# ...           ...       ...
# 1017179  0.973968  0.000000
# ...

# %%
df_normalized.rename(columns={0:'s',1:'p'},inplace=True)

# %%
from sklearn.cluster import KMeans
from sklearn import datasets
kmeans=KMeans(n_clusters=3)
kmeans.fit(df_normalized)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
centroids=kmeans.cluster_centers_

# %%
labels=kmeans.labels_

# %%
df_normalized['Cluster']=kmeans.labels_

# %%
df_normalized.Cluster.unique()
# Out:
# array([1, 0, 2], dtype=int64)

# %%
import matplotlib.pyplot as plt
for i in range(0,3):
    
#plt.scatter(x='Customers',y='Sales',data=df_new[df_new['Cluster']==1])
    plt.scatter(x='p',y='s',data=df_normalized[df_normalized['Cluster']==i])

    plt.show()

# %%
centroids=kmeans.cluster_centers_

# %%
df_normalized
# Out:
#                 s         p
# 0        0.000000  0.075122
# 1        0.000898  0.084597
# 2        0.001795  0.111126
# 3        0.002693  0.202761
# 4        0.003591  0.075663
# 5        0.004488  0.079724
# 6        0.005386  0.191391
# 7        0.006284  0.112750
# 8        0.007181  0.092989
# 9        0.008079  0.092177
# 10       0.008977  0.167298
# 11       0.009874  0.130211
# 12       0.010772  0.076881
# 13       0.011670  0.096102
# 14       0.012567  0.103682
# 15       0.013465  0.132512
# 16       0.014363  0.128045
# 17       0.015260  0.126692
# 18       0.016158  0.097185
# 19       0.017056  0.131835
# 20       0.017953  0.092312
# 21       0.018851  0.085679
# 22       0.019749  0.075799
# 23       0.020646  0.146454
# 24       0.021544  0.214672
# 25       0.022442  0.082702
# 26       0.023339  0.170953
# 27       0.024237  0.089740
# 28       0.025135  0.099756
# 29       0.026032  0.084597
# ...           ...       ...
# 1017179  0.973968  0.000000
# ...
