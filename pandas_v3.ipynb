# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\Vikash\\Downloads\\WorldCupMatches.csv")
df
# Out:
#         Year              Datetime              Stage  \
# 0     1930.0  13 Jul 1930 - 15:00             Group 1
# 1     1930.0  13 Jul 1930 - 15:00             Group 4
# 2     1930.0  14 Jul 1930 - 12:45             Group 2
# 3     1930.0  14 Jul 1930 - 14:50             Group 3
# 4     1930.0  15 Jul 1930 - 16:00             Group 1
# 5     1930.0  16 Jul 1930 - 14:45             Group 1
# 6     1930.0  17 Jul 1930 - 12:45             Group 2
# 7     1930.0  17 Jul 1930 - 14:45             Group 4
# 8     1930.0  18 Jul 1930 - 14:30             Group 3
# 9     1930.0  19 Jul 1930 - 12:50             Group 1
# 10    1930.0  19 Jul 1930 - 15:00             Group 1
# 11    1930.0  20 Jul 1930 - 13:00             Group 2
# 12    1930.0  20 Jul 1930 - 15:00             Group 4
# 13    1930.0  21 Jul 1930 - 14:50             Group 3
# 14    1930.0  22 Jul 1930 - 14:45             Group 1
# 15    1930.0  26 Jul 1930 - 14:45         Semi-finals
# ...

# %%
df.isna().sum()
# Out:
# Year                    3720
# Datetime                3720
# Stage                   3720
# Stadium                 3720
# City                    3720
# Home Team Name          3720
# Home Team Goals         3720
# Away Team Goals         3720
# Away Team Name          3720
# Win conditions          3720
# Attendance              3722
# Half-time Home Goals    3720
# Half-time Away Goals    3720
# Referee                 3720
# Assistant 1             3720
# Assistant 2             3720
# RoundID                 3720
# MatchID                 3720
# Home Team Initials      3720
# Away Team Initials      3720
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4572 entries, 0 to 4571
# Data columns (total 20 columns):
# Year                    852 non-null float64
# Datetime                852 non-null object
# Stage                   852 non-null object
# Stadium                 852 non-null object
# City                    852 non-null object
# Home Team Name          852 non-null object
# Home Team Goals         852 non-null float64
# Away Team Goals         852 non-null float64
# Away Team Name          852 non-null object
# Win conditions          852 non-null object
# Attendance              850 non-null float64
# Half-time Home Goals    852 non-null float64
# Half-time Away Goals    852 non-null float64
# Referee                 852 non-null object
# Assistant 1             852 non-null object
# Assistant 2             852 non-null object
# RoundID                 852 non-null float64
# MatchID                 852 non-null float64
# Home Team Initials      852 non-null object
# ...

# %%
a=df['Year'].median()
a
# Out:
# 1990.0

# %%
df['Year'].fillna(a,inplace=True)
df
# Out:
#         Year              Datetime              Stage  \
# 0     1930.0  13 Jul 1930 - 15:00             Group 1
# 1     1930.0  13 Jul 1930 - 15:00             Group 4
# 2     1930.0  14 Jul 1930 - 12:45             Group 2
# 3     1930.0  14 Jul 1930 - 14:50             Group 3
# 4     1930.0  15 Jul 1930 - 16:00             Group 1
# 5     1930.0  16 Jul 1930 - 14:45             Group 1
# 6     1930.0  17 Jul 1930 - 12:45             Group 2
# 7     1930.0  17 Jul 1930 - 14:45             Group 4
# 8     1930.0  18 Jul 1930 - 14:30             Group 3
# 9     1930.0  19 Jul 1930 - 12:50             Group 1
# 10    1930.0  19 Jul 1930 - 15:00             Group 1
# 11    1930.0  20 Jul 1930 - 13:00             Group 2
# 12    1930.0  20 Jul 1930 - 15:00             Group 4
# 13    1930.0  21 Jul 1930 - 14:50             Group 3
# 14    1930.0  22 Jul 1930 - 14:45             Group 1
# 15    1930.0  26 Jul 1930 - 14:45         Semi-finals
# ...

# %%
pd.pivot_table(index='Year',columns='Stadium',data=df)
# Out:
#             Attendance                                                   \
# Stadium Arena Amazonia Arena Fonte Nova Arena Pantanal Arena Pernambuco
# Year
# 1930.0             NaN              NaN            NaN              NaN
# 1934.0             NaN              NaN            NaN              NaN
# 1938.0             NaN              NaN            NaN              NaN
# 1950.0             NaN              NaN            NaN              NaN
# 1954.0             NaN              NaN            NaN              NaN
# 1958.0             NaN              NaN            NaN              NaN
# 1962.0             NaN              NaN            NaN              NaN
# 1966.0             NaN              NaN            NaN              NaN
# 1970.0             NaN              NaN            NaN              NaN
# 1974.0             NaN              NaN            NaN              NaN
# 1978.0             NaN              NaN            NaN              NaN
# ...

# %%
pwd
# Out:
# 'C:\\Users\\Vikash'

# %%
df.to_excel('abc.xlsx')

# %%
df.shape
# Out:
# (4572, 20)

# %%
#Top print only true condition value as row values
a=df[df['Away Team Goals']==0]
a
# Out:
#        Year              Datetime           Stage  \
# 1    1930.0  13 Jul 1930 - 15:00          Group 4
# 4    1930.0  15 Jul 1930 - 16:00          Group 1
# 5    1930.0  16 Jul 1930 - 14:45          Group 1
# 6    1930.0  17 Jul 1930 - 12:45          Group 2
# 7    1930.0  17 Jul 1930 - 14:45          Group 4
# 8    1930.0  18 Jul 1930 - 14:30          Group 3
# 9    1930.0  19 Jul 1930 - 12:50          Group 1
# 11   1930.0  20 Jul 1930 - 13:00          Group 2
# 12   1930.0  20 Jul 1930 - 15:00          Group 4
# 13   1930.0  21 Jul 1930 - 14:50          Group 3
# 30   1934.0  01 Jun 1934 - 16:30   Quarter-finals
# 31   1934.0  03 Jun 1934 - 16:30      Semi-finals
# 36   1938.0  05 Jun 1938 - 17:00      First round
# 41   1938.0  05 Jun 1938 - 18:30      First round
# 45   1938.0  12 Jun 1938 - 17:00   Quarter-finals
# 46   1938.0  12 Jun 1938 - 17:00   Quarter-finals
# 53   1950.0  24 Jun 1950 - 15:00          Group 1
# 54   1950.0  25 Jun 1950 - 15:00          Group 2
# ...

# %%
a[1:3]
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# 5  1930.0  16 Jul 1930 - 14:45   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 4      Argentina              1.0              0.0         France
# 5          Chile              3.0              0.0         Mexico
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 4                    23409.0                   0.0                   0.0
# 5                     9249.0                   1.0                   0.0
#
#                  Referee              Assistant 1                 Assistant 2  \
# 4    REGO Gilberto (BRA)     SAUCEDO Ulises (BOL)  RADULESCU Constantin (ROU)
# 5  CRISTOPHE Henry (BEL)  APHESTEGUY Martin (URU)         LANGENUS Jean (BEL)
#
#    RoundID  MatchID Home Team Initials Away Team Initials
# ...

# %%
df[1:3]
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 1                    18346.0                   2.0                   0.0
# 2                    24059.0                   2.0                   0.0
#
#                Referee               Assistant 1            Assistant 2  \
# 1    MACIAS Jose (ARG)  MATEUCCI Francisco (URU)  WARNKEN Alberto (CHI)
# 2  TEJADA Anibal (URU)   VALLARINO Ricardo (URU)    BALWAY Thomas (FRA)
#
#    RoundID  MatchID Home Team Initials Away Team Initials
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %%
#To get all columns name in list
b=list(df.columns)
b[7:9]
df[b[7:9]]
# Out:
#       Away Team Goals Away Team Name
# 0                 1.0         Mexico
# 1                 0.0        Belgium
# 2                 1.0         Brazil
# 3                 1.0           Peru
# 4                 0.0         France
# 5                 0.0         Mexico
# 6                 0.0        Bolivia
# 7                 0.0       Paraguay
# 8                 0.0           Peru
# 9                 0.0         France
# 10                3.0         Mexico
# 11                0.0        Bolivia
# 12                0.0        Belgium
# 13                0.0        Romania
# 14                1.0          Chile
# 15                1.0            USA
# 16                1.0     Yugoslavia
# 17                2.0      Argentina
# 18                2.0         France
# 19                2.0          Egypt
# 20                2.0    Netherlands
# 21                2.0      Argentina
# 22                2.0        Belgium
# 23                1.0         Brazil
# ...

# %%
#to get all numerical value columns
list(df.corr()[:0])
# Out:
# ['Year',
#  'Home Team Goals',
#  'Away Team Goals',
#  'Attendance',
#  'Half-time Home Goals',
#  'Half-time Away Goals',
#  'RoundID',
#  'MatchID']

# %%
#Train Test Concept
df.shape
df.shape[0]*0.43
# Out:
# 1965.96

# %%
round(df.shape[0]*0.20)
# Out:
# 914

# %%
Train=df[round(df.shape[0]*0.20):]
Train
# Out:
#         Year Datetime Stage Stadium City Home Team Name  Home Team Goals  \
# 914   1990.0      NaN   NaN     NaN  NaN            NaN              NaN
# 915   1990.0      NaN   NaN     NaN  NaN            NaN              NaN
# 916   1990.0      NaN   NaN     NaN  NaN            NaN              NaN
# 917   1990.0      NaN   NaN     NaN  NaN            NaN              NaN
# 918   1990.0      NaN   NaN     NaN  NaN            NaN              NaN
# 919   1990.0      NaN   NaN     NaN  NaN            NaN              NaN
# 920   1990.0      NaN   NaN     NaN  NaN            NaN              NaN
# 921   1990.0      NaN   NaN     NaN  NaN            NaN              NaN
# 922   1990.0      NaN   NaN     NaN  NaN            NaN              NaN
# 923   1990.0      NaN   NaN     NaN  NaN            NaN              NaN
# 924   1990.0      NaN   NaN     NaN  NaN            NaN              NaN
# 925   1990.0      NaN   NaN     NaN  NaN            NaN              NaN
# ...

# %%
#some sample data from data frame
df.sample(100)
# Out:
#         Year              Datetime                     Stage  \
# 3966  1990.0                   NaN                       NaN
# 3527  1990.0                   NaN                       NaN
# 958   1990.0                   NaN                       NaN
# 572   1998.0  03 Jul 1998 - 16:30             Quarter-finals
# 2404  1990.0                   NaN                       NaN
# 4287  1990.0                   NaN                       NaN
# 1161  1990.0                   NaN                       NaN
# 2687  1990.0                   NaN                       NaN
# 397   1986.0  15 Jun 1986 - 12:00                Round of 16
# 2726  1990.0                   NaN                       NaN
# 4259  1990.0                   NaN                       NaN
# 2893  1990.0                   NaN                       NaN
# 2377  1990.0                   NaN                       NaN
# 1726  1990.0                   NaN                       NaN
# ...

# %%
a=df.groupby('Home Team Name')
a.sum()
# Out:
#                                 Year  Home Team Goals  Away Team Goals  \
# Home Team Name
# Algeria                      11960.0              5.0             10.0
# Angola                        2006.0              0.0              1.0
# Argentina                   107228.0            111.0             44.0
# Australia                    11992.0              7.0             11.0
# Austria                      25562.0             31.0             17.0
# Belgium                      35908.0             27.0             16.0
# Bolivia                       1994.0              1.0              3.0
# Brazil                      162480.0            180.0             78.0
# Bulgaria                     13886.0             11.0             10.0
# Cameroon                     22014.0             11.0             23.0
# Canada                        1986.0              0.0              1.0
# Chile                        27644.0             25.0             11.0
# ...

# %%
a.sum().describe()
# Out:
#                 Year  Home Team Goals  Away Team Goals    Attendance  \
# count      78.000000        78.000000        78.000000  7.800000e+01
# mean    21683.282051        19.782051        11.166667  4.921805e+05
# std     28989.613228        31.325956        12.682350  7.596312e+05
# min      1958.000000         0.000000         0.000000  2.823000e+03
# 25%      3960.000000         2.000000         3.000000  6.778800e+04
# 50%      9984.000000         6.500000         6.500000  1.907715e+05
# 75%     27908.000000        24.250000        14.000000  4.760115e+05
# max    162480.000000       180.000000        78.000000  4.539969e+06
#
#        Half-time Home Goals  Half-time Away Goals       RoundID       MatchID
# count             78.000000             78.000000  7.800000e+01  7.800000e+01
# mean               7.743590              4.679487  1.164594e+08  6.700966e+08
# std               12.240486              5.667161  1.679641e+08  9.492077e+08
# ...

# %%
a.sum().transpose()
# Out:
# Home Team Name            Algeria      Angola     Argentina    Australia  \
# Year                      11960.0      2006.0  1.072280e+05      11992.0
# Home Team Goals               5.0         0.0  1.110000e+02          7.0
# Away Team Goals              10.0         1.0  4.400000e+01         11.0
# Attendance               153616.0     45000.0  2.915027e+06     236788.0
# Half-time Home Goals          3.0         0.0  4.800000e+01          1.0
# Half-time Away Goals          3.0         1.0  1.400000e+01          5.0
# RoundID                  506855.0  97410100.0  3.826860e+08   98172208.0
# MatchID               600250207.0  97410008.0  3.381577e+09  997848331.0
#
# Home Team Name         Austria       Belgium  Bolivia        Brazil  Bulgaria  \
# Year                   25562.0  3.590800e+04   1994.0  1.624800e+05   13886.0
# Home Team Goals           31.0  2.700000e+01      1.0  1.800000e+02      11.0
# ...

# %%
a.sum().T()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-0b04e6a2e675> in <module>()
# ----> 1 a.sum().T()
#
# TypeError: 'DataFrame' object is not callable

# %%
df[[df.isna().sum()]
# Out:
#   File "<ipython-input-8-e4dcddb4f89b>", line 1
#     df[[df.isna().sum()]
#                         ^
# SyntaxError: unexpected EOF while parsing
