# %%
import os
root='C:\\Users\\29265\\Desktop\\petraInt'
total_file=os.listdir(root)
total_file
# Out:
# ['cust', 'rev']

# %%
import os
total_file=os.listdir("C:\\Users\\29265\\Desktop\\\petraInt")
a=[]
for i in range(0,len(total_file)):
    
    x1='C:\\Users\\29265\\Desktop\\petraInt'
    x1=x1+'\\'+total_file[i]+'\\'+'config'
    #print(x1)
    a.append(x1)
totalConfigFile=[]
for i in range(0,len(a)):
    
    total_filecon=os.listdir(a[i])
    #print(total_filecon)
    totalConfigFile.append(total_filecon[0])
totalConfigFile
# Out:
# ['Config_Dimension_Cust.txt', 'Config_Dimension_Cust.txt']

# %%
#z='C:\\Users\\29265\\Desktop\\PetraImfFile\\Data_Dimension_Cust.csv'
f=open(a[0]+'\\'+totalConfigFile[0])
f.seek(0)
a=f.readlines()

# %%
total_filecon=os.listdir("C:\\Users\\29265\\Desktop\\petraInt\\cust\\config")
total_filecon
# Out:
# ['Config_Dimension_Cust.txt']

# %%
totalConfigFile=[]
for i in range(0,len(a)):
    
    total_filecon=os.listdir(a[i])
    print(total_filecon)
    totalConfigFile.append(total_filecon[0])
# Out:
# ['Config_Dimension_Cust.txt']
# ['Config_Dimension_Cust.txt']

# %%
totalConfigFile
# Out:
# ['Config_Dimension_Cust.txt', 'Config_Dimension_Cust.txt']

# %%
import os
total_file=os.listdir("C:\\Users\\29265\\Desktop\\\petraInt")
a=[]
for i in range(0,len(total_file)):
    
    x1='C:\\Users\\29265\\Desktop\\petraInt'
    x1=x1+'\\'+total_file[i]+'\\'+'data'
    #print(x1)
    a.append(x1)
totalConfigFile=[]
for i in range(0,len(a)):
    
    total_filecon=os.listdir(a[i])
    #print(total_filecon)
    totalConfigFile.append(total_filecon[0])
totalConfigFile
# Out:
# ['Data_Dimension_Cust.csv', 'Data_Dimension_Cust.csv']

# %% [markdown]
# # To get all config

# %%
import os
root='C:\\Users\\29265\\Desktop\\petraInt'
total_file=os.listdir(root)
total_file
total_file=os.listdir("C:\\Users\\29265\\Desktop\\\petraInt")
a=[]
for i in range(0,len(total_file)):
    
    x1='C:\\Users\\29265\\Desktop\\petraInt'
    x1=x1+'\\'+total_file[i]+'\\'+'config'
    #print(x1)
    a.append(x1)
totalConfigFile=[]
for i in range(0,len(a)):
    
    total_filecon=os.listdir(a[i])
    #print(total_filecon)
    totalConfigFile.append(total_filecon[0])
totalConfigFile
# Out:
# ['Config_Dimension_Cust.txt', 'Config_Dimension_Cust.txt']

# %%
#one example is below
f=open(a[0]+'\\'+totalConfigFile[0])
f.seek(0)
a=f.readlines()

# %% [markdown]
# # to get all data file

# %%
import os
root='C:\\Users\\29265\\Desktop\\petraInt'
total_file=os.listdir(root)
total_file
total_file=os.listdir("C:\\Users\\29265\\Desktop\\\petraInt")
a=[]
for i in range(0,len(total_file)):
    
    x1='C:\\Users\\29265\\Desktop\\petraInt'
    x1=x1+'\\'+total_file[i]+'\\'+'data'
    #print(x1)
    a.append(x1)
totalConfigFile=[]
for i in range(0,len(a)):
    
    total_filecon=os.listdir(a[i])
    #print(total_filecon)
    totalConfigFile.append(total_filecon[0])
totalConfigFile
# Out:
# ['Data_Dimension_Cust.csv', 'Data_Dimension_Cust.csv']

# %%
#one example is below
f=open(a[0]+'\\'+totalConfigFile[0])
f.seek(0)
a=f.readlines()
a
# Out:
# ['TimeZone,CustId,CustomerCode,LegalName,OriginalPetraCustomer,OwningCustomer,IsVendor,Type1,Banner,OwnershipType,Status,InactiveReason,AddressLine1,AddressLine2,PostCode,City,District,State,Country,CountryCode,BATCluster,SalesChannel,Directions,GeoCode,OutletType,Fax,Phone,Mobile,OutletSubType,ParentKey,CategoriesSold,MarketISO,IsDirectSalesCustomer,SAPCustomerId,SAPCustomerHierarchy,TaxId,IsBlockedToSales,BlockedToSalesReason,SAPVendorId,DaysOpenForBusiness,PreferredDaysForVisit,IsGroupOfAccounts,IsWholesaler,OwningCustomerCommercialName,BannerCommercialName,Parent1CommercialName,Parent2CommercialName,Parent3CommercialName,Parent4CommercialName,Parent5CommercialName,RecordTypeName,PaymentMethod,PaymentTerms,KeyAccountType,PrimaryContact,BannerLkp,TaxJurisdiction,Language,VATRegNo,IsB2BCustomer,EnableOnlineOrder,OriginalCustomer,IsCompetitor,DeliveryLeadTime,PricingProcedure,StateCode,DeactivationDate,ReactivationDate,TemporaryDeactivationDate,CreateDate,CreatedBy,LastUpdateDate,Las
# ...

# %% [markdown]
# # RND

# %%
import string
import re
f=open('C:\\Users\\29265\\Desktop\\PetraImfFile\\Config_Dimension_Cust.txt')
f.seek(0)
a=f.readlines()
a

id = []
for ln in a:
    if ln.startswith("MetaData:="):
        
        id.append(ln[10:])
#print(id)
lt_dict={}
for i in range(0,len(id)):
    zz=id[i]
    zz=zz.split(':=')
    pp = re.sub('[\n]', '', zz[2])
    lt_dict[zz[0]]=pp
print(lt_dict)
# Out:
# {'CustId': 'NonNullable', 'CommercialName': 'Nullable', 'CustomerCode': 'Nullable', 'LegalName': 'Nullable', 'OriginalPetraCustomer': 'Nullable', 'OwningCustomer': 'Nullable', 'IsVendor': 'Nullable', 'KeyAccountType': 'Nullable', 'Banner': 'Nullable', 'OwnershipType': 'Nullable', 'Status': 'Nullable', 'InactiveReason': 'Nullable', 'AddressLine1': 'Nullable', 'AddressLine2': 'Nullable', 'PostCode': 'Nullable', 'City': 'Nullable', 'District': 'Nullable', 'State': 'Nullable', 'Country': 'Nullable', 'SalesChannel': 'Nullable', 'Directions': 'Nullable', 'GeoCode': 'Nullable', 'OutletType': 'Nullable', 'Fax': 'Nullable', 'Phone': 'Nullable', 'Mobile': 'Nullable', 'OutletSubType': 'Nullable', 'ParentKey': 'Nullable', 'CategoriesSold': 'Nullable', 'MarketISO': 'NonNullable', 'IsDirectSalesCustomer': 'Nullable', 'SAPCustomerId': 'Nullable', 'SAPCustomerHierarchy': 'Nullable', 'TaxId': 'Nullable', 'IsBlockedToSales': 'Nullable', 'BlockedToSalesReason': 'Nullable', 'SAPVendorId': 'Nullable', 'D
# ...
