# %%
#campaign management
import pandas as pd
import numpy as np
test=pd.DataFrame(np.random.rand(20,3),columns=['sales','trans','profit'])

# %%
control=pd.DataFrame(np.random.rand(20,3),columns=['sales','trans','profit'])

# %%
a=[]
for i in test.columns:
    a.append(test[i].sum())

# %%
a
# Out:
# [11.206341457744246, 10.123921617030412, 11.292614975280818]

# %%
b=[]
for i in control.columns:
    b.append(control[i].sum())

# %%
a=np.array(a)
b=np.array(b)

# %%
lift=((a-b)/b)*100

# %%
lift
# Out:
# array([  4.42297504,  47.42964227,  15.02079459])

# %%
df
# Out:
#        sales     trans    profit
# 0   0.898011  0.561994  0.969126
# 1   0.132329  0.097755  0.001973
# 2   0.376606  0.871199  0.106806
# 3   0.359509  0.414028  0.230107
# 4   0.690986  0.447426  0.966672
# 5   0.196136  0.709405  0.279154
# 6   0.723218  0.639741  0.616703
# 7   0.059421  0.559728  0.973608
# 8   0.048965  0.933978  0.484052
# 9   0.864654  0.169139  0.366789
# 10  0.735380  0.288980  0.362700
# 11  0.142817  0.741897  0.643726
# 12  0.328034  0.214859  0.989908
# 13  0.820394  0.252316  0.873443
# 14  0.120600  0.959010  0.180403
# 15  0.662292  0.224285  0.406819
# 16  0.266874  0.257983  0.038942
# 17  0.618734  0.228054  0.448024
# 18  0.844071  0.508115  0.470501
# 19  0.727575  0.116496  0.880869

# %%
import numpy as np
a=np.random.rand(20,3)

# %%
a.shape
# Out:
# (20, 3)

# %%
#agglomaerative cluster
df3=pd.read_excel("C:\\Users\\29265\\Desktop\\data.xlsx",sheetname='Sheet7')
df3
#df3["is_duplicate"]= df3.duplicated()
 
#df3.describe

'''
for i in range(0,len((df3['is_duplicate']))):
    if df3['is_duplicate'][i]=='True':
        df3.iloc[]
    print (i)
'''
# Out:
# "\nfor i in range(0,len((df3['is_duplicate']))):\n    if df3['is_duplicate'][i]=='True':\n        df3.iloc[]\n    print (i)\n"

# %%
import pandas as pd
df3=pd.read_excel("C:\\Users\\29265\\Desktop\\data.xlsx",sheetname='Sheet7')
df3
a=df3[df3.duplicated(keep=False)]
a
# Out:
#     str  sales  units  txns
# 0  str1     34      1  2348
# 1  str1     34      1  2348
# 5  str6     40      1  2000
# 6  str1     34      1  2348
# 7  str6     40      1  2000

# %%
def FindDuplicateRow(df):
    a=df3[df3.duplicated(keep=False)]
    a

# %%
len(list(p.columns))
# Out:
# 5

# %%
import scipy.cluster.hierarchy as sch
import matplotlib.pyplot as plt
dendrogram = sch.dendrogram(sch.linkage(df3, method = 'single'))
plt.title('Dendrogram')
plt.xlabel('Customers')
plt.ylabel('Sales')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-30f52423c376> in <module>()
#       1 import scipy.cluster.hierarchy as sch
#       2 import matplotlib.pyplot as plt
# ----> 3 dendrogram = sch.dendrogram(sch.linkage(df3, method = 'single'))
#       4 plt.title('Dendrogram')
#       5 plt.xlabel('Customers')
#
# C:\Users\29265\AppData\Local\Continuum\Anaconda3\lib\site-packages\scipy\cluster\hierarchy.py in linkage(y, method, metric)
#     655         raise ValueError("Invalid method: {0}".format(method))
#     656
# --> 657     y = _convert_to_double(np.asarray(y, order='c'))
#     658
#     659     if y.ndim == 1:
#
# C:\Users\29265\AppData\Local\Continuum\Anaconda3\lib\site-packages\scipy\cluster\hierarchy.py in _convert_to_double(X)
#    1107 def _convert_to_double(X):
#    1108     if X.dtype != np.double:
# -> 1109         X = X.astype(np.double)
# ...

# %%
a=['a','b','z']
b=['a','d','c','f','b']
for i in range(0,len(a)):
    for j in range(0,len(b)):
        if a[i]==b[j]:
            break
            #print('match')
            #print(a[i])
        else:
            print(a[i])
# Out:
# b
# b
# b
# b
# z
# z
# z
# z
# z

# %%
#return all dublicates value in table uniquly
b
z=b.drop_duplicates()
z
# Out:
#     str sales units  txns
# 0  str1    34     1  2348
# 5  str6    40     1  2000

# %%
list(set(lst1)-set(lst2))
# Out:
# [1]

# %%
f=open('C:\\Users\\29265\\Desktop\\abc1.txt')
f.seek(0)
a=f.readlines()
a
# Out:
# ['ConfigFileInfo:=Author:=Mriganka\n',
#  'ConfigFileInfo:=CreatedDate:=2018-03-28\n',
#  'ConfigFileInfo:=Version:=1.0\n',
#  'ConfigFileInfo:=ModifiedDate:=2018-05-14\n',
#  'ConfigFileInfo:=ModifiedBy:=Mriganka\n',
#  "ConfigFileInfo:=ChangesHistory:=Changed CommercialName,OwnershipType,Status,District,Country,OutletType,RecordTypeName to Nullable fields defaulted with 'N/A'\n",
#  '\n',
#  '\n',
#  'MetaData:=CustId:=StringType(18):=NonNullable\n',
#  'MetaData:=CommercialName:=StringType(255):=Nullable\n',
#  'MetaData:=CustomerCode:=StringType(18):=Nullable\n',
#  'MetaData:=LegalName:=StringType(255):=Nullable\n',
#  'MetaData:=OriginalPetraCustomer:=StringType(255):=Nullable\n',
#  'MetaData:=OwningCustomer:=StringType(18):=Nullable\n',
#  'MetaData:=IsVendor:=IntegerType:=Nullable\n',
#  'MetaData:=KeyAccountType:=StringType(80):=Nullable\n',
#  'MetaData:=Banner:=StringType(30):=Nullable\n',
#  'MetaData:=OwnershipType:=StringType(30):=Nullable\n',
# ...

# %%
d={}
d['a']=1
d['b']=2
print(d)
len(d)
# Out:
# {'a': 1, 'b': 2}
# 2

# %%
import pandas as pd
a={'null value':['a','c','l']}
df1=pd.DataFrame(a)
df1
# Out:
#   null value
# 0          a
# 1          c
# 2          l

# %%
def getFileName(path):
    
    b=a.split('\\')
    d=len(b)-1
    f=b[d]
    b=f.split('.')
    return b[0]

# %%
a='C:\\Users\\29265\\Desktop\\data.xlsx'
val=getFileName(a)
val
# Out:
# 'data'

# %%
import xlsxwriter

# Create a new workbook and add a worksheet
workbook = xlsxwriter.Workbook('hyperlink.xlsx')
worksheet = workbook.add_worksheet('Hyperlinks')

# Format the first column
worksheet.set_column('A:A', 30)

# Add a sample alternative link format.
red_format = workbook.add_format({
    'font_color': 'red',
    'bold':       1,
    'underline':  1,
    'font_size':  12,
})

# Write some hyperlinks
worksheet.write_string('A1', 'ConfigFileName')  # Implicit format.
worksheet.write_url('A2', '#Hyperlinks!A1', string='config')
#worksheet.write_url('A3', 'http://www.python.org/', tip='Click here')
#worksheet.write_url('A4', 'http://www.python.org/', red_format)
#worksheet.write_url('A5', 'mailto:jmcnamara@cpan.org', string='Mail me')

# Write a URL that isn't a hyperlink
#worksheet.write_string('A11', 'http://www.python.org/')

workbook.close()

'''
import pandas as pd
df3=pd.read_excel("C:\\Users\\29265\\hyperlink.xlsx",sheetname='Hyperlinks')
df3
bb={'null':[23]}
df4=pd.DataFrame(bb)
df4
#writer = pd.ExcelWriter('Petra_Report.xlsx', engine='xlsxwriter')
df4.to_excel('C:\\Users\\29265\\hyperlink.xlsx', sheet_name='Hyperlinks',startcol=2,startrow=1)
#df4.to_excel(writer, sheet_name='Sheet2',startrow=2)
'''
# Out:
# '\nimport pandas as pd\ndf3=pd.read_excel("C:\\Users\\29265\\hyperlink.xlsx",sheetname=\'Hyperlinks\')\ndf3\nbb={\'null\':[23]}\ndf4=pd.DataFrame(bb)\ndf4\n#writer = pd.ExcelWriter(\'Petra_Report.xlsx\', engine=\'xlsxwriter\')\ndf4.to_excel(\'C:\\Users\\29265\\hyperlink.xlsx\', sheet_name=\'Hyperlinks\',startcol=2,startrow=1)\n#df4.to_excel(writer, sheet_name=\'Sheet2\',startrow=2)\n'

# %%
import pandas as pd
df = pd.DataFrame({'link':['=HYPERLINK("Petra_Report.xlsx#sheet2!E5", "some website")']})
df.to_excel('test.xlsx')

# %%
writer = pd.ExcelWriter('Petra_Report_link.xlsx', engine='xlsxwriter')
#dfblank
dfblank = pd.DataFrame({'link':['=HYPERLINK("Petra_Report_link.xlsx#sheet2!E5", "Config")'],'null':34})
dfblank.to_excel(writer, sheet_name='Summary_Report',startrow=2)
df4.to_excel(writer, sheet_name='Sheet2',startrow=2)

# %%
import pandas as pd
df_data=pd.read_csv("C:\\Users\\29265\\Desktop\\Data_Dimension_Cust.csv")
df_count_val=df_data.CustId.value_counts()
df_count_val=pd.DataFrame(df_count_val)#columns=['value','count']
#df_count_val
df_count_val_T=df_count_val.T

# %%
a=list(df_count_val_T['0016E00000ZXdVfQA3'])

# %%
a
# Out:
# [2]

# %%
pd.test()
# Out:
# running: pytest --skip-slow --skip-network C:\Users\29265\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas
# ============================= test session starts =============================
# platform win32 -- Python 3.6.1, pytest-3.0.7, py-1.4.33, pluggy-0.4.0
# rootdir: C:\Users\29265, inifile:
# collected 10236 items / 2 skipped
#
# AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\tests\test_algos.py ........................................................................................
# AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\tests\test_base.py .........................
# AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\tests\test_categorical.py ...................................................................................FFFFFF..FFFFFF................................................
# AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\tests\test_common.py ..............
# ...

# %%
df_count_val_T
df_count_val_T.loc[0:1,'0016E00000ZXdVfQA3']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-2904fe23aa11> in <module>()
#       1 df_count_val_T
# ----> 2 df_count_val_T.loc[0:1,'0016E00000ZXdVfQA3']
#
# C:\Users\29265\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1323             except (KeyError, IndexError):
#    1324                 pass
# -> 1325             return self._getitem_tuple(key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
#
# C:\Users\29265\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     834     def _getitem_tuple(self, tup):
#     835         try:
# --> 836             return self._getitem_lowerdim(tup)
#     837         except IndexingError:
#     838             pass
#
# ...

# %%
df_count_val_T.iloc[0:1,['0016E00000ZXdVfQA3']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-63939b99edc9> in <module>()
# ----> 1 df_count_val_T.iloc[0:1,['0016E00000ZXdVfQA3']]
#
# C:\Users\29265\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1323             except (KeyError, IndexError):
#    1324                 pass
# -> 1325             return self._getitem_tuple(key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
#
# C:\Users\29265\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1660     def _getitem_tuple(self, tup):
#    1661
# -> 1662         self._has_valid_tuple(tup)
#    1663         try:
#    1664             return self._getitem_lowerdim(tup)
#
# ...

# %%
len(b)
# Out:
# 5

# %%
b[4]
# Out:
# 'data.xlsx'

# %%
#ROC curve 
import numpy as np
from sklearn import metrics
y = np.array([1, 1, 2, 2])
scores = np.array([0.1, 0.4, 0.35, 0.8])
fpr, tpr, thresholds = metrics.roc_curve(y, scores, pos_label=2)
print(fpr)
#array([ 0. ,  0.5,  0.5,  1. ])
print(tpr)
#array([ 0.5,  0.5,  1. ,  1. ])
print(thresholds)
#array([ 0.8 ,  0.4 ,  0.35,  0.1 ])
# Out:
# [ 0.   0.5  0.5  1. ]
# [ 0.5  0.5  1.   1. ]
# [ 0.8   0.4   0.35  0.1 ]

# %%
p=[]
z={'cust':1,'b':3}
p.append(z)
df2=pd.DataFrame(p)

# %%
writer = pd.ExcelWriter('pandas_simple.xlsx', engine='xlsxwriter')
df1.to_excel(writer, sheet_name='Sheet1')  # Default position, cell A1.
df2.to_excel(writer, sheet_name='Sheet1', startcol=3)
writer.save()

# %%
pwd
# Out:
# 'C:\\Users\\29265'

# %%
from openpyxl import load_workbook

wb = load_workbook('C:\\Users\\29265\\pandas_simple.xlsx') 
ws = wb.get_sheet_by_name("Sheet1")

link = "pandas_simple.xlsx#sheet2!E5"

ws.cell(row=1, column=1).hyperlink = (link)

wb.save('C:\\Users\\29265\\pandas_simple.xlsx')

# %%
for i in d:
    if d[i]==3:
        print(d[i])

# %%
x=['a','b','c']
y=['x','z','l','a','c']
for i in range(0,len(x)):
    for j in range(0,len(y)):
        if x[i]==y[j]:
            print(x[i])
# Out:
# a
# c

# %%
lst1=[1,2,3]
lst2=[1,2,4]
final=list(set(lst1) & set(lst2))
final
# Out:
# [1, 2]

# %%
for i in len(lst1):
    for j in len(final):
        if lst1[i]==final[j]:

# %%
A=['a','b']
B=['b']
def a(x,y):
    return list(set(x)-set(y))

# %%
b=a(A,B)
b
# Out:
# ['a']

# %%
insection
# Out:
# [9, 4, 1]

# %%
list(set(lst1) & set(insection))
# Out:
# [9, 4, 1]

# %%
set(lst1) == set(insection)
# Out:
# True

# %%
list(set(lst1) & set(lst2))

# %%
#agglomaerative cluster
import pandas as pd
df3=pd.read_excel("C:\\Users\\29265\\Desktop\\data.xlsx",sheetname='Sheet6')
df3
# Out:
#    sales   units  trans
# 0      2     NaN      6
# 1      1     NaN      6
# 2      4     NaN      7
# 3      7     NaN      4
# 4      6     NaN      5
# 5     23     NaN     23
# 6     89    90.0     56
# 7   2000  2100.0   1000

# %%
def countNullValue_RemoveColHAve30Percent(df):
    total = df.isnull().sum().sort_values(ascending = False)
    percent = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending = False)
  
    missing_application_train_data=pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
 
    missing_application_train_data=missing_application_train_data.T
    for i in missing_application_train_data.columns:
        a=missing_application_train_data[i]
        if a[1]>30:
            df.drop(i,axis=1,inplace=True)
    return df

# %%
dfnew=countNullValue(df3)
dfnew
# Out:
#    sales  trans
# 0      2      6
# 1      1      6
# 2      4      7
# 3      7      4
# 4      6      5
# 5     23     23
# 6     89     56
# 7   2000   1000

# %%
a='abcv'
#a[1:2]='s'
id(a[2])
# Out:
# 1548828918648

# %%
a=()
a
# Out:
# ()

# %%
#list set,dictionary  is mutual but string ,number,tuple are immutable
a=(1,2,'3')
a[0]='2'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-478d2f82b060> in <module>()
#       1 a=(1,2,'3')
# ----> 2 a[0]='2'
#
# TypeError: 'tuple' object does not support item assignment

# %%
a={'a':1,'b':2}
a
# Out:
# {'a': 1, 'b': 2}

# %%
a['a']=2
a
# Out:
# {'a': 2, 'b': 2}

# %%
class Demo:
    a='vikash'
    def __init__(self,name):
        self.name=name
    def name1(self):
        print(self.name)
ob=Demo('kumar')
ob.a
ob.name
ob.name1()
# Out:
# kumar

# %%
Demo.a
# Out:
# 'vikash'

# %%
sum(x*x for x in range(1,10))
# Out:
# 285

# %%
sum(x*x for x in range(1,10))
# Out:
# 285

# %%
class poly:
    def sound(self):
        print('dog')
class more:
    def sound(self):
        print('cow')
ob1=poly()
ob1.sound()
# Out:
# dog

# %%
ob2=more()
ob2.sound()
# Out:
# cow

# %%
lambda x:x+1
# Out:
# <function __main__.<lambda>>

# %%
def ab(x):
    return x+1
map(ab,[4,5])

# %%
list_a = [1, 2, 3]
list_b = [10, 20, 30]
  
map(lambda x, y: x + y, list_a, list_b) # Output: [11, 22, 33]

# %%
a='vikash'
print(id(a))
# Out:
# 2058914333392

# %%
a='kumar'
a[0]='g'
print(id(a))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-a4503cee7719> in <module>()
#       1 a='kumar'
# ----> 2 a[0]='g'
#       3 print(id(a))
#
# TypeError: 'str' object does not support item assignment

# %%
a=[2,3,4]
b=[2,3,6]
a.append(b)
print(a)
# Out:
# [2, 3, 4, [2, 3, 6]]

# %%
a=[2,3,4]
b=[2,3,6]
a.extend(b)
print(a)
# Out:
# [2, 3, 4, 2, 3, 6]

# %%
a=[2,3,43]
b=2
a.append(b)
a
# Out:
# [2, 3, 43, 2]

# %%
x=[2,3]
y=9
try:
    x.extend(y)
    x
except:
    print("error")
# Out:
# error

# %%
sum=lambda x:x*x
sum(2)
# Out:
# 4

# %%
a=[2,3,4]
x=map(lambda x:x+2,a)
list(x)
# Out:
# [4, 5, 6]

# %%
# filter
a=[1,2,3,4]
p=filter(lambda x: x%2==0,a)
list(p)
# Out:
# [2, 4]

# %%
a='vikash'
sum=''
for i in a:
    sum=i+sum
print(sum)
# Out:
# hsakiv

# %%
a[::-1]
# Out:
# 'hsakiv'

# %%
def NameSum(*args):#*args will give list of value with non keyword
    nameadd=''
    for i in args:
        nameadd=nameadd+i
    print(nameadd)
NameSum('vikash','kumar','ravi')
# Out:
# vikashkumarravi

# %%
#**kargs#variable-length argument dictionary to a function.

def getCid(**kargs):
    for key,val in kargs.items():
        print(str(key)+": "+val)
        print('my key for {} is {} '.format(key,val))
getCid(k='vikash',v='kumar')
# Out:
# k: vikash
# my key for k is vikash
# v: kumar
# my key for v is kumar

# %%
def print_values(**kwargs):
    for key, value in kwargs.items():
        print("The value of {} is {}".format(key, value))

print_values(
            name_1="Alex",
            name_2="Gray",
            name_3="Harper",
            name_4="Phoenix",
            name_5="Remy",
            name_6="Val"
        )
# Out:
# The value of name_1 is Alex
# The value of name_2 is Gray
# The value of name_3 is Harper
# The value of name_4 is Phoenix
# The value of name_5 is Remy
# The value of name_6 is Val

# %%
#to=Email[0].replace('TO:\xa0','')
a='vikash@'
print(id(a))
a=a.replace('@','')
print(id(a))
# Out:
# 2058914417496
# 2058914467488

# %%
for i in range(0,4):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
for i in xrange(0,4):
    print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-95-ddd9ec718b6e> in <module>()
# ----> 1 for i in xrange(0,4):
#       2     print(i)
#
# NameError: name 'xrange' is not defined

# %%
#decorator #generator

# %%
#CODE
#input='abcacd'
def getkey(input):
    key=[]
    for i in input:
        #print(i)
        if i not in key:
            key.append(i)
    return key

# %%
def getOccurencerr(input,key):
    result=[]
    for i in key:#['a', 'b', 'c', 'd']
        count=0
        for j in input:#abcacd
            if i==j:
                count=count+1
        dict={i:count}
        result.append(dict)
    return result

# %%
key=getkey('abcacd')
#res=getOccurencerr('abcacd',key)
#res

# %%
#key value camparison then pick
xx='abcacd'
xx=list(xx)
for i in range(0,len(xx)):
    x=xx[i]
    res=getOccurencerr(xx,key)
    for i in range(0,len(res)):
        #need to check the key value with character
        try:
            if(res[i][x])>1:
                print("for key: "+x+"occurence is :"+res[i][x])
        except:
           # print("ex")
            continue

# %%
p=[{'a': 2}, {'b': 1}, {'c': 2}, {'d': 1}]

# %%
p[1]['b']
# Out:
# 1

# %%
a=[1,2,6]
a[::1]
# Out:
# [1, 2, 6]

# %%
key
# Out:
# ['a', 'b', 'c', 'd']

# %%
key=getkey('zbzcacd')

res=[]
for i in key:#['a', 'b', 'c', 'd']
    count=0
    for j in input:#abcacd
        if i==j:
            count=count+1
    dict={i:count}
    res.append(dict)

# %%
key
# Out:
# ['z', 'b', 'c', 'a', 'd']

# %%
felement=key[0]
felement
# Out:
# 'z'

# %%
res
# Out:
# [{'a': 2}, {'b': 1}, {'c': 2}, {'d': 1}]

# %%
def abc():
    return a

# %%
abc()
# Out:
# [{'b': 1}]

# %%
from collections import Counter
a=[1,2,2,2,'h']
b=Counter(a)
b['h']
# Out:
# 1

# %%
a='aabcd'
b='abef'
x=[]
y=[]
for i in a:
    x.append(i)
for i in b:
    y.append(i)

# %%
x=set(x)
y=set(y)

# %%
p=x-y
p
temp=''
for i in p:
    temp=temp+i
temp
# Out:
# 'dc'

# %%
q=y-x
for i in q:
    temp=temp+i
temp
# Out:
# 'dcef'

# %%
p.append(q)
p
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-111-497900b3b0d4> in <module>()
# ----> 1 p.append(q)
#       2 p
#
# AttributeError: 'set' object has no attribute 'append'

# %%
input=[2342,1234,2345,7689]
#find the odd one
#1st sort order in each entry
#then use loop to check for all the input
#a=2343
for k in input:
    a=str(k)
    temp=[]
    for i in a:
        temp.append(i)
    temp
    for i in temp:
        for j in temp:
            if i>j:  
                print(a)
                break
# Out:
# 2342
# 2342
# 1234
# 1234
# 1234
# 2345
# 2345
# 2345
# 7689
# 7689
# 7689
