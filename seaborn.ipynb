# %%
# %matplotlib inline
import seaborn as sns
df=sns.load_dataset("titanic")
v=df.corr()
sns.heatmap(v)

# %%
v=df.corr()
v
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
sns.heatmap(v,annot=True)

# %%
sns.heatmap(v,annot=True,cmap='hot')

# %%
import matplotlib.pyplot as pt
pt.figure(figsize=(10,10))
sns.heatmap(v,annot=True,cmap='hot',linewidths=2,square=False)

# %%
sns.barplot(x='survived',y='age',hue='pclass',data=df)

# %%
sns.factorplot(x='survived',y='age',row='pclass',data=df,col='pclass')

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
sns.stripplot(x='survived',y='age',data=df)

# %%
sns.factorplot(x='survived',y='age',data=df)

# %%
sns.violinplot(x='survived',y='age',data=df)

# %%
sns.swarmplot(x='survived',y='age',data=df)

# %%
sns.boxplot(x='survived',y='age',data=df)

# %%
sns.violinplot(x='survived',y='age',data=df,size=10)

# %%
sns.factorplot(x='survived',y='age',data=df,size=10)

# %%
sns.factorplot(x='survived',y='age',data=df,size=5,kind='strip')

# %%
sns.lmplot(x='age',y='fare',data=df)

# %%
sns.lmplot(x='age',y='fare',data=df,row='survived',hue='adult_male')

# %%
sns.set_style("darkgrid")
sns.lmplot(x='age',y='fare',data=df,row='survived',hue='adult_male')

# %%
sns.distplot(df['fare'],kde=False)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
sns.jointplot(x='fare',y='age',data=df,kind="scatter")

# %%
sns.jointplot(x='fare',y='age',data=df,kind="reg")

# %%
sns.jointplot(x='fare',y='age',data=df,kind="hex")

# %%
sns.jointplot(x='fare',y='age',data=df,kind="kde")
