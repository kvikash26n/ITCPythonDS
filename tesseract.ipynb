# %%
#import Image
from PIL import Image
from tesseract import image_to_string

print (image_to_string(Image.open("C:\\Users\\29265\\Desktop\\pic.jpg")))
#print image_to_string(Image.open('test-english.jpg'), lang='eng')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-0c180a8fda13> in <module>()
#       1 #import Image
#       2 from PIL import Image
# ----> 3 from tesseract import image_to_string
#       4
#       5 print (image_to_string(Image.open("C:\\Users\\29265\\Desktop\\pic.jpg")))
#
# ModuleNotFoundError: No module named 'tesseract'

# %%
from PIL import Image
from pytesseract import image_to_string

myText = image_to_string(Image.open("C:\\Users\\29265\\Desktop\\pic.jpg"),config='-psm 10')
#myText = image_to_string(Image.open("C:\Users\29265\Desktop\pic.jpg"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\29265\AppData\Local\Continuum\Anaconda3\lib\site-packages\pytesseract\pytesseract.py in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice)
#     169     try:
# --> 170         proc = subprocess.Popen(cmd_args, **subprocess_args())
#     171     except OSError:
#
# C:\Users\29265\AppData\Local\Continuum\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     706                                 errread, errwrite,
# --> 707                                 restore_signals, start_new_session)
#     708         except:
#
# ...
