# %%
x = ['ab', 'cd']
for i in x:
    i.upper()
print(x)
# Out:
# ['ab', 'cd']

# %%
x = ['ab', 'cd']
for i in x:
x.append(i.upper())
print(x)

# %%
i = 1
while True:
    if i%3 == 0:
        break
    print(i)
    i=i+1
# Out:
# 1
# 2

# %%
i = 5
while True:
    if i%0O11 == 0:
        break
    print(i)
    i =i+ 1
# Out:
# 5
# 6
# 7
# 8

# %%
i = 5
while True:
    if i%0O9 == 0:
        break
    print(i)
    i =i+ 1
# Out:
#   File "<ipython-input-14-ceacd09f68de>", line 3
#     if i%0O9 == 0:
#           ^
# SyntaxError: invalid token

# %%
True = False
while True:
    print(True)
    break
# Out:
#   File "<ipython-input-2-e285fae84622>", line 1
#     True = False
#                 ^
# SyntaxError: can't assign to keyword
